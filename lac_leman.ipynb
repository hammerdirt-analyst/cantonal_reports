# %%
# %load_ext watermark
import pandas as pd
import numpy as np
import datetime as dt
from IPython.display import Markdown as md
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import seaborn as sns
import json

# this defines the css rules for the note-book table displays
header_row = {'selector': 'th:nth-child(1)', 'props': f'background-color: #FFF; text-align:right'}
even_rows = {"selector": 'tr:nth-child(even)', 'props': f'background-color: rgba(139, 69, 19, 0.08);'}
odd_rows = {'selector': 'tr:nth-child(odd)', 'props': 'background: #FFF;'}
table_font = {'selector': 'tr', 'props': 'font-size: 10px;'}
table_data = {'selector': 'td', 'props': 'padding: 6px;'}
table_caption = {'selector': 'caption', 'props': 'font-size: 14px; font-style: italic; caption-side: bottom; text-align: left; margin-top: 10px'}
table_css_styles = [even_rows, odd_rows, table_font, header_row, table_caption]

table_large_data = {'selector': 'tr', 'props': 'font-size: 14px;'}
table_large_font = [even_rows, odd_rows, table_large_data, header_row, table_caption]

def rotateText(x):
    return 'writing-mode: vertical-lr; transform: rotate(-180deg);  padding:10px; margins:0; vertical-align: baseline;'

cantons = ["Vaud", "Genève", "Valais"]
cantons_avoisinante = "Valais, Vaud, Genève"
other_cantons = ["Vaud", "Genève", "Valais"]
lake = "Le Léman"

def save_json(filename, data):
    with open(f"resources/{filename}", "w") as afile:
        json.dump(data, afile)

def open_json(filename):
    with open(f"resources/{filename}", "r") as afile:
        data = json.load(afile)
        return data
    

display_names = open_json("french_display_names.json")

land_use_names = open_json("french_land_use_names.json")

material_names = open_json("french_material_names.json")

group_names = open_json("french_group_names.json")

french_names = open_json("french_code_translations.json")

# land use
land_use = pd.read_csv("resources/work_land_use.csv")
lu_map = land_use[land_use.use == "Siedl"][["slug", "scaled"]].set_index("slug")

all_data = pd.read_csv("resources/survey_work_data.csv", low_memory=False)

all_data = all_data[['loc_date', 'slug', 'city', 'water_name_slug', 'date', 'doy', 'Project', 'code', 'pcs/m', 'quantity', 'canton', 'zone']].copy()
all_data["date"] = pd.to_datetime(all_data["date"])
all_data = all_data[all_data.code != "G216"]

gh = pd.read_csv("resources/lac_leman_regions.csv")
gh.set_index("slug", inplace=True, drop=True)

codes_of_interest = [
    "G95",
    "G70",
    "Gfrags",
    "Gfoam",
    "G112",
    "G27",
    "G30",
    "G67",
    "G10",
    "Gcaps",
]

all_data = all_data[all_data.code.isin(codes_of_interest)].copy()
all_data = all_data[all_data.canton.isin(other_cantons)].copy()




all_x = all_data[all_data.canton.isin(other_cantons)].drop_duplicates(["code", "loc_date"]).copy()
all_data  = all_x[all_x.zone.isin(["lac"])].copy()
all_data["region"] = all_data.slug.apply(lambda x: gh.loc[x, "alabel"])
lac_riv = all_data.copy()

operations={
    "loc_date":"nunique", 
    "city":"nunique", 
    "quantity":"sum",
    "slug":"nunique"
}
summary_data = lac_riv.groupby(["region"]).agg(operations)

summary_data = summary_data.astype("int")

# %% [markdown]
# # Lac Léman

# %% [markdown]
# > What the use of P [the significance level] implies, therefore, is that a hypothesis that may be true may be rejected because it has not predicted observable results that have not occurred. _Harold Jeffereys_
#
# > It appears to be a quite general principle that, whenever there is a randomized way of doing something, then there is a nonrandomized way that delivers better performance but requires more thought. _ET Jaynes_

# %%
dims = pd.read_csv("resources/work_dimensions.csv")

land_use_of_interest = [
    'Siedl', 
    'Wald',
    'Stadtzentr',
    'Reben', 
    'Obstanlage',
    'undefined',
    'infrastructure',
    'recreation',
    'Strasse'
]


def dimensional_summary_data(dims, survey_data, request, zones=["lac", "rivière", "montagne"]):
    dfs = []
    for label in zones:
        d_f = dims[dims.slug.isin(survey_data[survey_data[request] == label].slug.unique())].copy()
        d_f[request] = label
        dfs.append(d_f)
    dimensions = pd.concat(dfs)
    d_sum = dimensions.groupby(request).agg({"area":"sum", "length":"sum", "time":"sum"})
    return dimensions, d_sum

dimensional_summary, d_sum = dimensional_summary_data(dims, lac_riv, "region", zones=lac_riv["region"].unique())

summary_by_zone = pd.concat([summary_data, d_sum], axis=1, ignore_index=False)
summary_by_zone["hours"] = (summary_by_zone["time"]/60).round(2)
summary_by_zone.drop("time", inplace=True, axis=1)
summary_by_zone.loc["total", : ] = summary_by_zone.sum()

# %%
caption_french = f"Historique des échantillonnages {lake} : Le nombre d'échantillons et l'ampleur de l'effort par contexte. Remarque : les heures correspondent au temps passé à compter et à collecter."

summary_by_zone.index.name = None
summary_by_zone.rename(columns=display_names, inplace=True)
summary_by_zone = summary_by_zone.astype("int")
summary_by_zone.style.set_table_styles(table_large_font).format('{:,}' ).set_caption(caption_french)
# Out:
# <style type="text/css">
# #T_53900 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_53900 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_53900 tr {
#   font-size: 14px;
# }
# #T_53900 th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_53900 caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# </style>
# <table id="T_53900">
#   <caption>Historique des échantillonnages Le Léman : Le nombre d'échantillons et l'ampleur de l'effort par contexte. Remarque : les heures correspondent au temps passé à compter et à collecter.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53900_level0_col0" class="col_heading level0 col0" >échantillons</th>
#       <th id="T_53900_level0_col1" class="col_heading level0 col1" >municipalités</th>
#       <th id="T_53900_level0_col2" class="col_heading level0 col2" >quantité</th>
#       <th id="T_53900_level0_col3" class="col_heading level0 col3" >site</th>
#       <th id="T_53900_level0_col4" class="col_heading level0 col4" >m²</th>
#       <th id="T_53900_level0_col5" class="col_heading level0 col5" >mètres</th>
#       <th id="T_53900_level0_col6" class="col_heading level0 col6" >heures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53900_level0_row0" class="row_heading level0 row0" >Grand lac</th>
#       <td id="T_53900_row0_col0" class="data row0 col0" >83</td>
#       <td id="T_53900_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_53900_row0_col2" class="data row0 col2" >16,810</td>
#       <td id="T_53900_row0_col3" class="data row0 col3" >21</td>
#       <td id="T_53900_row0_col4" class="data row0 col4" >37,526</td>
#       <td id="T_53900_row0_col5" class="data row0 col5" >8,222</td>
#       <td id="T_53900_row0_col6" class="data row0 col6" >343</td>
#     </tr>
#     <tr>
#       <th id="T_53900_level0_row1" class="row_heading level0 row1" >Haut lac</th>
#       <td id="T_53900_row1_col0" class="data row1 col0" >157</td>
#       <td id="T_53900_row1_col1" class="data row1 col1" >9</td>
#       <td id="T_53900_row1_col2" class="data row1 col2" >42,162</td>
#       <td id="T_53900_row1_col3" class="data row1 col3" >20</td>
#       <td id="T_53900_row1_col4" class="data row1 col4" >13,796</td>
#       <td id="T_53900_row1_col5" class="data row1 col5" >4,314</td>
#       <td id="T_53900_row1_col6" class="data row1 col6" >162</td>
#     </tr>
#     <tr>
#       <th id="T_53900_level0_row2" class="row_heading level0 row2" >Petit lac</th>
#       <td id="T_53900_row2_col0" class="data row2 col0" >79</td>
#       <td id="T_53900_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_53900_row2_col2" class="data row2 col2" >9,829</td>
#       <td id="T_53900_row2_col3" class="data row2 col3" >15</td>
#       <td id="T_53900_row2_col4" class="data row2 col4" >16,669</td>
#       <td id="T_53900_row2_col5" class="data row2 col5" >4,568</td>
#       <td id="T_53900_row2_col6" class="data row2 col6" >111</td>
#     </tr>
#     <tr>
#       <th id="T_53900_level0_row3" class="row_heading level0 row3" >total</th>
#       <td id="T_53900_row3_col0" class="data row3 col0" >319</td>
#       <td id="T_53900_row3_col1" class="data row3 col1" >25</td>
#       <td id="T_53900_row3_col2" class="data row3 col2" >68,801</td>
#       <td id="T_53900_row3_col3" class="data row3 col3" >56</td>
#       <td id="T_53900_row3_col4" class="data row3 col4" >67,992</td>
#       <td id="T_53900_row3_col5" class="data row3 col5" >17,104</td>
#       <td id="T_53900_row3_col6" class="data row3 col6" >617</td>
#     </tr>
#   </tbody>
# </table>

# %%
summary_data_l = lac_riv.groupby(["canton"]).agg(operations)

dimensional_summary_l, d_sum_l = dimensional_summary_data(dims, lac_riv, "canton", zones=lac_riv["canton"].unique())

summary_by_canton = pd.concat([summary_data_l, d_sum_l], axis=1, ignore_index=False)
summary_by_canton["hours"] = (summary_by_canton["time"]/60).round(2)
summary_by_canton.drop("time", inplace=True, axis=1)
summary_by_canton.loc["total", : ] = summary_by_canton.sum()

caption_french = f"Historique des échantillonnages {lake} : Le nombre d'échantillons et l'ampleur de l'effort par canton. Remarque : les heures correspondent au temps passé à compter et à collecter."

summary_by_canton.index.name = None
summary_by_canton.rename(columns=display_names, inplace=True)
summary_by_canton = summary_by_canton.astype("int")
summary_by_canton.style.set_table_styles(table_large_font).format('{:,}' ).set_caption(caption_french)
# Out:
# <style type="text/css">
# #T_74ab2 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_74ab2 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_74ab2 tr {
#   font-size: 14px;
# }
# #T_74ab2 th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_74ab2 caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# </style>
# <table id="T_74ab2">
#   <caption>Historique des échantillonnages Le Léman : Le nombre d'échantillons et l'ampleur de l'effort par canton. Remarque : les heures correspondent au temps passé à compter et à collecter.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74ab2_level0_col0" class="col_heading level0 col0" >échantillons</th>
#       <th id="T_74ab2_level0_col1" class="col_heading level0 col1" >municipalités</th>
#       <th id="T_74ab2_level0_col2" class="col_heading level0 col2" >quantité</th>
#       <th id="T_74ab2_level0_col3" class="col_heading level0 col3" >site</th>
#       <th id="T_74ab2_level0_col4" class="col_heading level0 col4" >m²</th>
#       <th id="T_74ab2_level0_col5" class="col_heading level0 col5" >mètres</th>
#       <th id="T_74ab2_level0_col6" class="col_heading level0 col6" >heures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74ab2_level0_row0" class="row_heading level0 row0" >Genève</th>
#       <td id="T_74ab2_row0_col0" class="data row0 col0" >50</td>
#       <td id="T_74ab2_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_74ab2_row0_col2" class="data row0 col2" >8,692</td>
#       <td id="T_74ab2_row0_col3" class="data row0 col3" >11</td>
#       <td id="T_74ab2_row0_col4" class="data row0 col4" >16,119</td>
#       <td id="T_74ab2_row0_col5" class="data row0 col5" >4,432</td>
#       <td id="T_74ab2_row0_col6" class="data row0 col6" >108</td>
#     </tr>
#     <tr>
#       <th id="T_74ab2_level0_row1" class="row_heading level0 row1" >Valais</th>
#       <td id="T_74ab2_row1_col0" class="data row1 col0" >17</td>
#       <td id="T_74ab2_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_74ab2_row1_col2" class="data row1 col2" >8,367</td>
#       <td id="T_74ab2_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_74ab2_row1_col4" class="data row1 col4" >4,718</td>
#       <td id="T_74ab2_row1_col5" class="data row1 col5" >1,794</td>
#       <td id="T_74ab2_row1_col6" class="data row1 col6" >74</td>
#     </tr>
#     <tr>
#       <th id="T_74ab2_level0_row2" class="row_heading level0 row2" >Vaud</th>
#       <td id="T_74ab2_row2_col0" class="data row2 col0" >252</td>
#       <td id="T_74ab2_row2_col1" class="data row2 col1" >19</td>
#       <td id="T_74ab2_row2_col2" class="data row2 col2" >51,742</td>
#       <td id="T_74ab2_row2_col3" class="data row2 col3" >43</td>
#       <td id="T_74ab2_row2_col4" class="data row2 col4" >47,155</td>
#       <td id="T_74ab2_row2_col5" class="data row2 col5" >10,878</td>
#       <td id="T_74ab2_row2_col6" class="data row2 col6" >435</td>
#     </tr>
#     <tr>
#       <th id="T_74ab2_level0_row3" class="row_heading level0 row3" >total</th>
#       <td id="T_74ab2_row3_col0" class="data row3 col0" >319</td>
#       <td id="T_74ab2_row3_col1" class="data row3 col1" >25</td>
#       <td id="T_74ab2_row3_col2" class="data row3 col2" >68,801</td>
#       <td id="T_74ab2_row3_col3" class="data row3 col3" >56</td>
#       <td id="T_74ab2_row3_col4" class="data row3 col4" >67,992</td>
#       <td id="T_74ab2_row3_col5" class="data row3 col5" >17,104</td>
#       <td id="T_74ab2_row3_col6" class="data row3 col6" >617</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Objets d'intérêt

# %%
lac_riv["fail"] = lac_riv['pcs/m'] > 0
fail_rates = lac_riv.groupby("code", as_index=False).fail.sum()
n_samps = lac_riv.loc_date.nunique()
fail_rates["rate"]= fail_rates.fail/n_samps
fail_rates = fail_rates.sort_values(by="rate", ascending=False)
failed = fail_rates[fail_rates.rate >= .5].code.unique()

abundant = lac_riv.groupby("code", as_index=False).quantity.sum()
abundant_c = abundant.sort_values(by="quantity", ascending=False)[:10].code.unique()

most_common_codes = list(set([*abundant, *failed]))

mc_data = lac_riv[lac_riv.code.isin(codes_of_interest)].groupby("code", as_index=False).agg({"quantity":"sum", "pcs/m":"median", "fail":"sum"})
mc_data["fail_rate"] = (mc_data.fail/n_samps).round(2)
mc_data["q_weight"] = (mc_data.quantity/abundant.quantity.sum()).round(2)
mc_data["object"] = mc_data.code.apply(lambda x: french_names[x])
mc_data = mc_data[["object", "quantity", "pcs/m", "q_weight", "fail_rate"]]

mc_data = mc_data.sort_values(by="quantity", ascending=False)
mc_data["quantity"] = mc_data.quantity.astype("int")
mc_data["pcs/m"] = mc_data["pcs/m"].round(2)
mc_data.set_index("object", drop=True, inplace=True)
mc_data.index.name = None
mc_data.rename(columns=display_names).style.set_table_styles(table_large_font).format('{:,}')
# Out:
# <style type="text/css">
# #T_71886 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_71886 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_71886 tr {
#   font-size: 14px;
# }
# #T_71886 th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_71886 caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# </style>
# <table id="T_71886">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71886_level0_col0" class="col_heading level0 col0" >quantité</th>
#       <th id="T_71886_level0_col1" class="col_heading level0 col1" >pcs/m</th>
#       <th id="T_71886_level0_col2" class="col_heading level0 col2" >% de totale</th>
#       <th id="T_71886_level0_col3" class="col_heading level0 col3" >fail_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71886_level0_row0" class="row_heading level0 row0" >Plastiques fragmentés</th>
#       <td id="T_71886_row0_col0" class="data row0 col0" >17,235</td>
#       <td id="T_71886_row0_col1" class="data row0 col1" >0.56</td>
#       <td id="T_71886_row0_col2" class="data row0 col2" >0.25</td>
#       <td id="T_71886_row0_col3" class="data row0 col3" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_71886_level0_row1" class="row_heading level0 row1" >Mégots et filtres à cigarettes</th>
#       <td id="T_71886_row1_col0" class="data row1 col0" >16,342</td>
#       <td id="T_71886_row1_col1" class="data row1 col1" >0.51</td>
#       <td id="T_71886_row1_col2" class="data row1 col2" >0.24</td>
#       <td id="T_71886_row1_col3" class="data row1 col3" >0.88</td>
#     </tr>
#     <tr>
#       <th id="T_71886_level0_row2" class="row_heading level0 row2" >Polystyrène expansé fragmenté</th>
#       <td id="T_71886_row2_col0" class="data row2 col0" >12,296</td>
#       <td id="T_71886_row2_col1" class="data row2 col1" >0.24</td>
#       <td id="T_71886_row2_col2" class="data row2 col2" >0.18</td>
#       <td id="T_71886_row2_col3" class="data row2 col3" >0.83</td>
#     </tr>
#     <tr>
#       <th id="T_71886_level0_row3" class="row_heading level0 row3" >Emballages de bonbons, de snacks</th>
#       <td id="T_71886_row3_col0" class="data row3 col0" >6,686</td>
#       <td id="T_71886_row3_col1" class="data row3 col1" >0.21</td>
#       <td id="T_71886_row3_col2" class="data row3 col2" >0.1</td>
#       <td id="T_71886_row3_col3" class="data row3 col3" >0.9</td>
#     </tr>
#     <tr>
#       <th id="T_71886_level0_row4" class="row_heading level0 row4" >Coton-tige</th>
#       <td id="T_71886_row4_col0" class="data row4 col0" >4,774</td>
#       <td id="T_71886_row4_col1" class="data row4 col1" >0.14</td>
#       <td id="T_71886_row4_col2" class="data row4 col2" >0.07</td>
#       <td id="T_71886_row4_col3" class="data row4 col3" >0.8</td>
#     </tr>
#     <tr>
#       <th id="T_71886_level0_row5" class="row_heading level0 row5" >Couvercles de bouteilles en plastique</th>
#       <td id="T_71886_row5_col0" class="data row5 col0" >3,904</td>
#       <td id="T_71886_row5_col1" class="data row5 col1" >0.13</td>
#       <td id="T_71886_row5_col2" class="data row5 col2" >0.06</td>
#       <td id="T_71886_row5_col3" class="data row5 col3" >0.87</td>
#     </tr>
#     <tr>
#       <th id="T_71886_level0_row6" class="row_heading level0 row6" >Bâche, feuille plastique industrielle</th>
#       <td id="T_71886_row6_col0" class="data row6 col0" >3,227</td>
#       <td id="T_71886_row6_col1" class="data row6 col1" >0.06</td>
#       <td id="T_71886_row6_col2" class="data row6 col2" >0.05</td>
#       <td id="T_71886_row6_col3" class="data row6 col3" >0.6</td>
#     </tr>
#     <tr>
#       <th id="T_71886_level0_row7" class="row_heading level0 row7" >Pellets industriels (GPI)</th>
#       <td id="T_71886_row7_col0" class="data row7 col0" >2,686</td>
#       <td id="T_71886_row7_col1" class="data row7 col1" >0.0</td>
#       <td id="T_71886_row7_col2" class="data row7 col2" >0.04</td>
#       <td id="T_71886_row7_col3" class="data row7 col3" >0.25</td>
#     </tr>
#     <tr>
#       <th id="T_71886_level0_row8" class="row_heading level0 row8" >Cartouches de fusil de chasse</th>
#       <td id="T_71886_row8_col0" class="data row8 col0" >1,028</td>
#       <td id="T_71886_row8_col1" class="data row8 col1" >0.01</td>
#       <td id="T_71886_row8_col2" class="data row8 col2" >0.01</td>
#       <td id="T_71886_row8_col3" class="data row8 col3" >0.5</td>
#     </tr>
#     <tr>
#       <th id="T_71886_level0_row9" class="row_heading level0 row9" >Emballage fast food</th>
#       <td id="T_71886_row9_col0" class="data row9 col0" >623</td>
#       <td id="T_71886_row9_col1" class="data row9 col1" >0.0</td>
#       <td id="T_71886_row9_col2" class="data row9 col2" >0.01</td>
#       <td id="T_71886_row9_col3" class="data row9 col3" >0.38</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Communes et zones d'intérêt

# %%
cities_in_canton = ', '.join(lac_riv.city.unique())

munix = f'__Municipalités:__ {cities_in_canton}'
md(munix)
# Out:
# __Municipalités:__ Aubonne, Genève, Bouveret, Clarens, Crans, Cully, Gland, Grangettes, Hermance, Lutry, La Tour-de-Peilz, Saint-Sulpice (VD), Vevey, Versoix, Préverenges, Rolle, Savonière, Tolochenaz, Vidy, Montreux, Bourg-en-Lavaux, Saint-Gingolph, Morges, Allaman, Lausanne

# %%
rivers = ', '.join([x for x in all_x[all_x.zone == 'rivière'].water_name_slug.unique() if x != 'la-thiele'])
riverx = f'__Rivières:__ {rivers}'
md(riverx)
# Out:
# __Rivières:__ arve, rhone, ognonnaz

# %% [markdown]
# ### Utilisation des sols: (m² utilisé)/ (m² disponible)
#
# L'utilisation du sol des sites étudiés en par rapport à l'utilisation du sol d'autres cantons sur le lac.
#
# Chaque lieu d'inventaire est géolocalisé au centre d'un hexagone de 3 000 mètres. L'ampleur des attributs de l'occupation et de l'utilisation des sols à l'intérieur de cet hexagone est calculée. Cette procédure peut améliorer le choix des lieux d'échantillonnage. Les résultats ont déjà été utilisés pour identifier les caractéristiques d'un lieu d'inventaire qui peuvent conduire à l'accumulation de certains déchets.

# %%
fig, axs = plt.subplots(2, 5, figsize=(7,6), sharey=True)

valais_locs = lac_riv.slug.unique()
# region_locs = not_valais.slug.unique()

index_order = [
    'Siedl',
    'infrastructure', 
    'Wald',
    'Obstanlage',
    'Undefined',
    'recreation',
    'Reben',
    'Stadtzentr',
  
]

ax_s = {
    'Siedl':[0,0],
    'infrastructure':[0,1], 
    'Wald':[0,2],
    'Obstanlage':[0,3],
    'undefined':[0,4],
    'recreation':[1,0],
    'Reben':[1,1],
    'Stadtzentr':[1,2],
}

l_used = land_use[land_use.use.isin(land_use_of_interest)]
v_land_use = land_use[land_use.slug.isin(valais_locs)].copy()
# r_land_use = land_use[land_use.slug.isin(region_locs)].copy()

no_streets = [x for x in land_use_of_interest if x != "Strasse"]

for i, name in enumerate(ax_s.keys()):
    
    row = ax_s[name][0]
    column = ax_s[name][1]
    ax = axs[row, column]
    # sns.stripplot(data = v_land_use[v_land_use.use == name], y = "scaled", color="magenta", zorder=20, size=6, ax=ax)
    sns.boxplot(data= v_land_use[v_land_use.use == name], y="scaled",  ax=ax, color='slategray')
    ax.set_xticks([0], [land_use_names[name]])
    ax.set_ylabel("")

axs[1, 4].axis('off')
a_space = axs[1, 3]
a_space.axis('off')
h = [Patch(facecolor='slategray', edgecolor='black', label='Color Patch')]
l = [cantons_avoisinante ]
a_space.legend(h,l, bbox_to_anchor=(0,1), loc="upper left")

plt.tight_layout()
plt.subplots_adjust(wspace=.1)
plt.show()

# %% [markdown]
# ## Résultats des inventaires: pcs/m
#
# La densité est calculée en additionnant tous les objets trouvés pour chaque jour et lieu d'échantillonnage. La somme pour chaque échantillon est ensuite divisée par la longueur du rivage, de la rive ou du tronçon de sentier. Pour un exemple, voir le rapport fédéral sur le calcul des lignes de base. [Baselines](https://hammerdirt-analyst.github.io/IQAASL-End-0f-Sampling-2021/baselines.html).

# %%
# # make the survey total from the list of available codes
# # survey_totals from valais
vs_jt = lac_riv.groupby(["loc_date", "date", "region"], as_index=False)["pcs/m"].sum()

# all other locations
# lake
# lake_jt=not_valais[not_valais.zone == "lac"].groupby(["loc_date", "date"], as_index=False)["pcs/m"].sum()

# rivers
# rhn_jt = not_valais[not_valais.zone == "rivière"].groupby(["loc_date", "date"], as_index=False)["pcs/m"].sum()

#alpes
# alp_jt = not_valais[not_valais.zone == "montagne"].groupby(["loc_date", "date"], as_index=False)["pcs/m"].sum()

french_caption = "La densité totale par échantillon pour les 74 objets d'intérêt. \
Le premier prélèvement en Valais date de 2016. Les prélèvements en rivière \
et en montagne ont été réalisés lors du rapport fédéral."

fig, ax = plt.subplots()
sns.scatterplot(data=vs_jt, x="date", y="pcs/m", hue="region", zorder=20, palette={'Haut lac':'royalblue', 'Grand lac':'saddlebrown', 'Petit lac': 'black'}, ax=ax)
# sns.scatterplot(data=lake_jt,  x="date", y="pcs/m", zorder=0, color='royalblue', alpha=0.2, ax=ax, label='Le Léman')
# sns.scatterplot(data=rhn_jt, x="date", y="pcs/m", zorder=1, color='slategray', alpha=0.2, ax=ax, label='Autres rivières')
# sns.scatterplot(data=alp_jt, x="date", y="pcs/m", zorder=1, color='saddlebrown', alpha=0.2, ax=ax, label='Les Alpes')
ax.set_ylim(-1, 60)
ax.legend(bbox_to_anchor=(0, 1), loc="upper left", ncol=2)
ax.set_xlabel("")
plt.show()

# %% [markdown]
# ### Répartition de la densité des déchets
#
# __a définir__

# %% [markdown]
# __Répartition des objets selon matériel.__

# %%
dfCodes = pd.read_csv("resources/codes.csv")
dfCodes.set_index("code", drop=True, inplace=True)
dfCodes.loc["Gcaps", ["material", "description", "parent_code", "groupname"]] = "Plastic", "Plastic bottle tops", "Parent code", 'food and drink'

code_d = dfCodes["description"]
code_m = dfCodes["material"]
code_g = dfCodes["groupname"]

caption_material_fr = "Total des objets par type de matériau. Tous les échantillons."

lac_riv["material"] = lac_riv.code.apply(lambda x: code_m.loc[x])
material_totals = lac_riv.groupby("material", as_index=False).quantity.sum()
material_totals["quantity"] = material_totals.quantity.astype(int)
material_totals["material"] = material_totals.material.apply(lambda x: material_names[x])
material_totals["q_weight"] = (material_totals.quantity/material_totals.quantity.sum()).round(3)
material_totals = material_totals.set_index("material", drop=True)
material_totals.sort_values(by="quantity", ascending=False, inplace=True)
material_totals.index.name = None
material_totals.rename(columns=display_names).style.set_table_styles(table_large_font).format('{:,}').set_caption(caption_material_fr)
# Out:
# <style type="text/css">
# #T_1b156 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_1b156 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_1b156 tr {
#   font-size: 14px;
# }
# #T_1b156 th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_1b156 caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# </style>
# <table id="T_1b156">
#   <caption>Total des objets par type de matériau. Tous les échantillons.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b156_level0_col0" class="col_heading level0 col0" >quantité</th>
#       <th id="T_1b156_level0_col1" class="col_heading level0 col1" >% de totale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b156_level0_row0" class="row_heading level0 row0" >Plastique</th>
#       <td id="T_1b156_row0_col0" class="data row0 col0" >68,801</td>
#       <td id="T_1b156_row0_col1" class="data row0 col1" >1.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Objets d'intérêt résultats municipaux: pcs/m

# %%
objects_city = lac_riv[lac_riv.code.isin(codes_of_interest)].groupby(["city","code"], as_index=False)["pcs/m"].mean()
objects_city["object"] = objects_city.code.apply(lambda x: french_names[x])
municipal_results = objects_city.pivot(columns="city", index="object", values="pcs/m").fillna(0)
municipal_results = municipal_results.round(2)
municipal_results.index.name = None
municipal_results.columns.name = None
municipal_results = municipal_results.T
dist = municipal_results.style.set_table_styles(table_large_font).format('{:,}').applymap_index(rotateText, axis=1)
dist.background_gradient(axis=None, vmin= municipal_results.min().min(), vmax= municipal_results.max().max(), cmap="YlOrBr")
# Out:
# <style type="text/css">
# #T_69c78 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_69c78 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_69c78 tr {
#   font-size: 14px;
# }
# #T_69c78 th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_69c78 caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# #T_69c78_row0_col0, #T_69c78_row19_col0, #T_69c78_row20_col5, #T_69c78_row22_col2 {
#   background-color: #fffbd2;
#   color: #000000;
# }
# #T_69c78_row0_col1, #T_69c78_row6_col8, #T_69c78_row7_col2, #T_69c78_row16_col0, #T_69c78_row20_col2, #T_69c78_row24_col7 {
#   background-color: #fffddd;
#   color: #000000;
# }
# #T_69c78_row0_col2, #T_69c78_row18_col1, #T_69c78_row23_col8 {
#   background-color: #fff8c0;
#   color: #000000;
# }
# #T_69c78_row0_col3, #T_69c78_row2_col6, #T_69c78_row10_col8, #T_69c78_row17_col9, #T_69c78_row22_col6, #T_69c78_row23_col0 {
#   background-color: #fffbd3;
#   color: #000000;
# }
# #T_69c78_row0_col4, #T_69c78_row2_col7, #T_69c78_row4_col1, #T_69c78_row7_col4, #T_69c78_row9_col1, #T_69c78_row10_col5, #T_69c78_row14_col4, #T_69c78_row17_col7, #T_69c78_row19_col4, #T_69c78_row21_col3, #T_69c78_row22_col1 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_69c78_row0_col5, #T_69c78_row3_col5, #T_69c78_row11_col5 {
#   background-color: #fff9c7;
#   color: #000000;
# }
# #T_69c78_row0_col6, #T_69c78_row4_col5, #T_69c78_row14_col2 {
#   background-color: #fffbd0;
#   color: #000000;
# }
# #T_69c78_row0_col7, #T_69c78_row1_col0, #T_69c78_row1_col1, #T_69c78_row1_col2, #T_69c78_row1_col4, #T_69c78_row1_col7, #T_69c78_row2_col0, #T_69c78_row2_col4, #T_69c78_row3_col0, #T_69c78_row3_col4, #T_69c78_row4_col0, #T_69c78_row4_col4, #T_69c78_row4_col7, #T_69c78_row5_col0, #T_69c78_row5_col1, #T_69c78_row5_col2, #T_69c78_row5_col3, #T_69c78_row5_col4, #T_69c78_row5_col6, #T_69c78_row5_col7, #T_69c78_row5_col9, #T_69c78_row6_col0, #T_69c78_row6_col1, #T_69c78_row6_col2, #T_69c78_row6_col4, #T_69c78_row6_col5, #T_69c78_row6_col7, #T_69c78_row6_col9, #T_69c78_row7_col1, #T_69c78_row8_col1, #T_69c78_row8_col4, #T_69c78_row8_col7, #T_69c78_row9_col0, #T_69c78_row9_col4, #T_69c78_row10_col0, #T_69c78_row10_col1, #T_69c78_row10_col2, #T_69c78_row10_col3, #T_69c78_row10_col4, #T_69c78_row10_col7, #T_69c78_row10_col9, #T_69c78_row11_col7, #T_69c78_row12_col1, #T_69c78_row12_col4, #T_69c78_row13_col0, #T_69c78_row13_col2, #T_69c78_row13_col4, #T_69c78_row13_col7, #T_69c78_row14_col7, #T_69c78_row15_col1, #T_69c78_row15_col2, #T_69c78_row15_col4, #T_69c78_row15_col7, #T_69c78_row16_col1, #T_69c78_row16_col4, #T_69c78_row17_col0, #T_69c78_row17_col1, #T_69c78_row17_col4, #T_69c78_row20_col0, #T_69c78_row20_col1, #T_69c78_row20_col4, #T_69c78_row20_col7, #T_69c78_row20_col9, #T_69c78_row21_col1, #T_69c78_row21_col4, #T_69c78_row21_col7, #T_69c78_row22_col4, #T_69c78_row23_col7, #T_69c78_row24_col0, #T_69c78_row24_col1, #T_69c78_row24_col4, #T_69c78_row24_col9 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_69c78_row0_col8, #T_69c78_row11_col6 {
#   background-color: #fee89d;
#   color: #000000;
# }
# #T_69c78_row0_col9, #T_69c78_row1_col6, #T_69c78_row8_col2, #T_69c78_row15_col0, #T_69c78_row24_col3 {
#   background-color: #fffddb;
#   color: #000000;
# }
# #T_69c78_row1_col3, #T_69c78_row1_col9, #T_69c78_row4_col3, #T_69c78_row5_col5, #T_69c78_row13_col1, #T_69c78_row13_col3, #T_69c78_row13_col5, #T_69c78_row19_col1, #T_69c78_row21_col0, #T_69c78_row21_col2 {
#   background-color: #fffee2;
#   color: #000000;
# }
# #T_69c78_row1_col5, #T_69c78_row3_col1, #T_69c78_row8_col0, #T_69c78_row13_col9, #T_69c78_row14_col1, #T_69c78_row17_col3, #T_69c78_row22_col0, #T_69c78_row23_col1 {
#   background-color: #fffee0;
#   color: #000000;
# }
# #T_69c78_row1_col8, #T_69c78_row3_col2, #T_69c78_row4_col9, #T_69c78_row7_col0, #T_69c78_row12_col3, #T_69c78_row14_col0 {
#   background-color: #fffcd8;
#   color: #000000;
# }
# #T_69c78_row2_col1, #T_69c78_row8_col6, #T_69c78_row11_col1, #T_69c78_row18_col7, #T_69c78_row20_col3 {
#   background-color: #fffedf;
#   color: #000000;
# }
# #T_69c78_row2_col2, #T_69c78_row3_col6, #T_69c78_row9_col6 {
#   background-color: #fffacd;
#   color: #000000;
# }
# #T_69c78_row2_col3, #T_69c78_row10_col6, #T_69c78_row19_col7, #T_69c78_row24_col2 {
#   background-color: #fffcd6;
#   color: #000000;
# }
# #T_69c78_row2_col5, #T_69c78_row6_col3, #T_69c78_row11_col4, #T_69c78_row13_col6, #T_69c78_row15_col3, #T_69c78_row17_col2, #T_69c78_row21_col5, #T_69c78_row22_col7, #T_69c78_row22_col9, #T_69c78_row23_col4 {
#   background-color: #fffee1;
#   color: #000000;
# }
# #T_69c78_row2_col8 {
#   background-color: #fee99e;
#   color: #000000;
# }
# #T_69c78_row2_col9, #T_69c78_row3_col9, #T_69c78_row14_col5, #T_69c78_row17_col5, #T_69c78_row18_col6, #T_69c78_row23_col2 {
#   background-color: #fffcd4;
#   color: #000000;
# }
# #T_69c78_row3_col3, #T_69c78_row16_col9 {
#   background-color: #ffface;
#   color: #000000;
# }
# #T_69c78_row3_col7, #T_69c78_row15_col5, #T_69c78_row24_col5 {
#   background-color: #fff8c2;
#   color: #000000;
# }
# #T_69c78_row3_col8 {
#   background-color: #fec24d;
#   color: #000000;
# }
# #T_69c78_row4_col2, #T_69c78_row14_col3, #T_69c78_row15_col8, #T_69c78_row22_col3 {
#   background-color: #fffcd7;
#   color: #000000;
# }
# #T_69c78_row4_col6 {
#   background-color: #fec95b;
#   color: #000000;
# }
# #T_69c78_row4_col8 {
#   background-color: #fedf88;
#   color: #000000;
# }
# #T_69c78_row5_col8, #T_69c78_row6_col6, #T_69c78_row7_col3, #T_69c78_row16_col2, #T_69c78_row16_col3, #T_69c78_row21_col9 {
#   background-color: #fffddc;
#   color: #000000;
# }
# #T_69c78_row7_col5, #T_69c78_row9_col7, #T_69c78_row18_col4, #T_69c78_row20_col6 {
#   background-color: #fffacb;
#   color: #000000;
# }
# #T_69c78_row7_col6, #T_69c78_row23_col9 {
#   background-color: #fff6b9;
#   color: #000000;
# }
# #T_69c78_row7_col7, #T_69c78_row8_col3 {
#   background-color: #fffdd9;
#   color: #000000;
# }
# #T_69c78_row7_col8, #T_69c78_row19_col5 {
#   background-color: #feeda6;
#   color: #000000;
# }
# #T_69c78_row7_col9, #T_69c78_row12_col9 {
#   background-color: #fff4b5;
#   color: #000000;
# }
# #T_69c78_row8_col5, #T_69c78_row11_col2, #T_69c78_row19_col2 {
#   background-color: #fff5b8;
#   color: #000000;
# }
# #T_69c78_row8_col8, #T_69c78_row9_col2 {
#   background-color: #fff9c5;
#   color: #000000;
# }
# #T_69c78_row8_col9, #T_69c78_row12_col5, #T_69c78_row19_col3 {
#   background-color: #fff9c9;
#   color: #000000;
# }
# #T_69c78_row9_col3, #T_69c78_row16_col5, #T_69c78_row21_col6, #T_69c78_row21_col8, #T_69c78_row22_col5, #T_69c78_row23_col3 {
#   background-color: #fffbcf;
#   color: #000000;
# }
# #T_69c78_row9_col5 {
#   background-color: #fee596;
#   color: #000000;
# }
# #T_69c78_row9_col8 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_69c78_row9_col9, #T_69c78_row18_col3 {
#   background-color: #fee28e;
#   color: #000000;
# }
# #T_69c78_row11_col0 {
#   background-color: #fff9c6;
#   color: #000000;
# }
# #T_69c78_row11_col3, #T_69c78_row15_col9 {
#   background-color: #fffaca;
#   color: #000000;
# }
# #T_69c78_row11_col8 {
#   background-color: #fed26d;
#   color: #000000;
# }
# #T_69c78_row11_col9 {
#   background-color: #fed471;
#   color: #000000;
# }
# #T_69c78_row12_col0 {
#   background-color: #fff8c4;
#   color: #000000;
# }
# #T_69c78_row12_col2, #T_69c78_row20_col8 {
#   background-color: #fff1b0;
#   color: #000000;
# }
# #T_69c78_row12_col6 {
#   background-color: #fedd84;
#   color: #000000;
# }
# #T_69c78_row12_col7, #T_69c78_row14_col8 {
#   background-color: #fff7be;
#   color: #000000;
# }
# #T_69c78_row12_col8 {
#   background-color: #fea231;
#   color: #000000;
# }
# #T_69c78_row13_col8, #T_69c78_row17_col8 {
#   background-color: #fed87a;
#   color: #000000;
# }
# #T_69c78_row14_col6, #T_69c78_row18_col5 {
#   background-color: #fedb80;
#   color: #000000;
# }
# #T_69c78_row14_col9, #T_69c78_row16_col7 {
#   background-color: #ffeea9;
#   color: #000000;
# }
# #T_69c78_row15_col6 {
#   background-color: #feab39;
#   color: #000000;
# }
# #T_69c78_row16_col6 {
#   background-color: #fff1ae;
#   color: #000000;
# }
# #T_69c78_row16_col8 {
#   background-color: #feeba2;
#   color: #000000;
# }
# #T_69c78_row17_col6 {
#   background-color: #fff3b2;
#   color: #000000;
# }
# #T_69c78_row1

# %% [markdown]
# ### Résultats par utilité d'objet: pcs/m

# %% [markdown]
# L'utilité d'un objet est basée sur l'utilisation de l'objet avant qu'il ne soit jeté ou sur la description de l'objet si l'utilisation d'origine n'est pas déterminée.
#
# * __eaux usées :__ objets rejetés par les stations d'épuration des eaux, y compris les objets susceptibles d'être jetés dans les toilettes
# * __microplastiques (< 5 mm) :__ plastiques fragmentés et résines plastiques de préproduction
# * __infrastructures :__ éléments liés à la construction et à l'entretien des bâtiments, des routes et de l'approvisionnement en eau et en électricité
# * __alimentation et boissons :__ tous les matériaux liés à la consommation d'aliments et de boissons
# * __agriculture :__ principalement les feuilles industrielles, c'est-à-dire le paillage et les couvertures de rangs, les serres, la fumigation des sols, l'enrubannage des balles. Comprend les plastiques durs pour les clôtures agricoles, les pots de fleurs, etc.
# * __tabac :__ principalement les filtres de cigarettes, y compris tout le matériel lié au tabagisme
# * __Loisirs :__ objets liés aux sports et aux loisirs, tels que la pêche, la chasse, la randonnée, etc.
# * __Emballages non alimentaires et boissons :__ matériaux d'emballage non identifiés comme étant liés à l'alimentation, aux boissons ou au tabac.
# * __fragments de plastique :__ morceaux de plastique d'origine ou d'utilisation indéterminée
# * __articles personnels :__ accessoires, hygiène et vêtements

# %%
lac_riv["groupname"] = lac_riv.code.apply(lambda x: code_g.loc[x])

cg_agg = lac_riv.groupby(["loc_date", "city", "groupname"], as_index=False)["pcs/m"].sum()
cg_agg["groupname"] = cg_agg.groupname.apply(lambda x: group_names[x])
cg_agg_group = cg_agg.groupby(["city","groupname"], as_index=False)["pcs/m"].median()

cg_display = cg_agg_group.pivot(columns="city", index="groupname", values=["pcs/m"])
cg_display=cg_display.round(2)
cg_display.index.name = None
cg_display.columns = cg_display.columns.droplevel()
cg_display.fillna(0, inplace=True)
cg_display.columns.name = None
cg_display = cg_display.T

dist = cg_display.style.set_table_styles(table_large_font).format('{:,}').applymap_index(rotateText, axis=1)
dist.background_gradient(axis=None, vmin=cg_display.min().min(), vmax= cg_display.max().max(), cmap="YlOrBr")
# Out:
# <style type="text/css">
# #T_6c2c2 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_6c2c2 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_6c2c2 tr {
#   font-size: 14px;
# }
# #T_6c2c2 th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_6c2c2 caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# #T_6c2c2_row0_col0, #T_6c2c2_row22_col2 {
#   background-color: #fffbd3;
#   color: #000000;
# }
# #T_6c2c2_row0_col1 {
#   background-color: #fff4b5;
#   color: #000000;
# }
# #T_6c2c2_row0_col2 {
#   background-color: #fff5b8;
#   color: #000000;
# }
# #T_6c2c2_row0_col3 {
#   background-color: #fee18c;
#   color: #000000;
# }
# #T_6c2c2_row0_col4, #T_6c2c2_row4_col4, #T_6c2c2_row11_col0, #T_6c2c2_row18_col7, #T_6c2c2_row23_col3 {
#   background-color: #fffdd9;
#   color: #000000;
# }
# #T_6c2c2_row0_col5, #T_6c2c2_row17_col4 {
#   background-color: #fffddc;
#   color: #000000;
# }
# #T_6c2c2_row0_col6, #T_6c2c2_row1_col0, #T_6c2c2_row1_col2, #T_6c2c2_row1_col5, #T_6c2c2_row1_col6, #T_6c2c2_row2_col0, #T_6c2c2_row3_col0, #T_6c2c2_row4_col0, #T_6c2c2_row4_col5, #T_6c2c2_row4_col6, #T_6c2c2_row5_col0, #T_6c2c2_row5_col2, #T_6c2c2_row5_col4, #T_6c2c2_row5_col5, #T_6c2c2_row5_col6, #T_6c2c2_row5_col7, #T_6c2c2_row6_col0, #T_6c2c2_row6_col2, #T_6c2c2_row6_col4, #T_6c2c2_row6_col5, #T_6c2c2_row6_col6, #T_6c2c2_row7_col0, #T_6c2c2_row7_col5, #T_6c2c2_row7_col6, #T_6c2c2_row8_col0, #T_6c2c2_row8_col5, #T_6c2c2_row8_col6, #T_6c2c2_row8_col7, #T_6c2c2_row9_col0, #T_6c2c2_row9_col5, #T_6c2c2_row10_col0, #T_6c2c2_row10_col2, #T_6c2c2_row10_col4, #T_6c2c2_row10_col5, #T_6c2c2_row10_col6, #T_6c2c2_row11_col6, #T_6c2c2_row12_col5, #T_6c2c2_row12_col6, #T_6c2c2_row13_col0, #T_6c2c2_row13_col2, #T_6c2c2_row13_col6, #T_6c2c2_row13_col7, #T_6c2c2_row14_col6, #T_6c2c2_row15_col2, #T_6c2c2_row15_col5, #T_6c2c2_row15_col6, #T_6c2c2_row16_col5, #T_6c2c2_row17_col0, #T_6c2c2_row17_col5, #T_6c2c2_row17_col6, #T_6c2c2_row18_col6, #T_6c2c2_row19_col6, #T_6c2c2_row20_col0, #T_6c2c2_row20_col4, #T_6c2c2_row20_col5, #T_6c2c2_row20_col6, #T_6c2c2_row21_col0, #T_6c2c2_row21_col2, #T_6c2c2_row21_col5, #T_6c2c2_row21_col6, #T_6c2c2_row22_col4, #T_6c2c2_row22_col5, #T_6c2c2_row22_col6, #T_6c2c2_row23_col5, #T_6c2c2_row23_col6, #T_6c2c2_row24_col0, #T_6c2c2_row24_col4, #T_6c2c2_row24_col5 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_6c2c2_row0_col7, #T_6c2c2_row2_col4, #T_6c2c2_row3_col4, #T_6c2c2_row21_col3, #T_6c2c2_row24_col2 {
#   background-color: #fffcd4;
#   color: #000000;
# }
# #T_6c2c2_row1_col1, #T_6c2c2_row5_col3, #T_6c2c2_row6_col3, #T_6c2c2_row12_col4, #T_6c2c2_row20_col2, #T_6c2c2_row24_col6 {
#   background-color: #fffddd;
#   color: #000000;
# }
# #T_6c2c2_row1_col3, #T_6c2c2_row11_col2, #T_6c2c2_row16_col4, #T_6c2c2_row19_col0 {
#   background-color: #fffcd8;
#   color: #000000;
# }
# #T_6c2c2_row1_col4, #T_6c2c2_row2_col6, #T_6c2c2_row3_col5, #T_6c2c2_row10_col1, #T_6c2c2_row14_col5, #T_6c2c2_row19_col5, #T_6c2c2_row22_col0 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_6c2c2_row1_col7, #T_6c2c2_row3_col2, #T_6c2c2_row8_col1, #T_6c2c2_row15_col0, #T_6c2c2_row20_col7 {
#   background-color: #fffddb;
#   color: #000000;
# }
# #T_6c2c2_row2_col1, #T_6c2c2_row11_col4, #T_6c2c2_row14_col1, #T_6c2c2_row22_col7 {
#   background-color: #fffbd0;
#   color: #000000;
# }
# #T_6c2c2_row2_col2, #T_6c2c2_row3_col7, #T_6c2c2_row7_col7, #T_6c2c2_row20_col1, #T_6c2c2_row22_col1 {
#   background-color: #fffacd;
#   color: #000000;
# }
# #T_6c2c2_row2_col3, #T_6c2c2_row18_col2 {
#   background-color: #fee89d;
#   color: #000000;
# }
# #T_6c2c2_row2_col5, #T_6c2c2_row10_col7, #T_6c2c2_row14_col2 {
#   background-color: #fffedf;
#   color: #000000;
# }
# #T_6c2c2_row2_col7, #T_6c2c2_row9_col7, #T_6c2c2_row12_col0 {
#   background-color: #fffbd2;
#   color: #000000;
# }
# #T_6c2c2_row3_col1, #T_6c2c2_row17_col7, #T_6c2c2_row24_col1 {
#   background-color: #fff3b4;
#   color: #000000;
# }
# #T_6c2c2_row3_col3 {
#   background-color: #fec34f;
#   color: #000000;
# }
# #T_6c2c2_row3_col6 {
#   background-color: #ffface;
#   color: #000000;
# }
# #T_6c2c2_row4_col1, #T_6c2c2_row14_col3 {
#   background-color: #fffcd6;
#   color: #000000;
# }
# #T_6c2c2_row4_col2, #T_6c2c2_row7_col1, #T_6c2c2_row8_col3, #T_6c2c2_row8_col4, #T_6c2c2_row9_col6, #T_6c2c2_row10_col3, #T_6c2c2_row15_col3, #T_6c2c2_row16_col1 {
#   background-color: #fffcd7;
#   color: #000000;
# }
# #T_6c2c2_row4_col3 {
#   background-color: #fee697;
#   color: #000000;
# }
# #T_6c2c2_row4_col7, #T_6c2c2_row14_col7 {
#   background-color: #feeaa1;
#   color: #000000;
# }
# #T_6c2c2_row5_col1, #T_6c2c2_row6_col7, #T_6c2c2_row7_col2, #T_6c2c2_row8_col2, #T_6c2c2_row11_col5, #T_6c2c2_row13_col5, #T_6c2c2_row17_col2, #T_6c2c2_row21_col7 {
#   background-color: #fffee2;
#   color: #000000;
# }
# #T_6c2c2_row6_col1, #T_6c2c2_row13_col4, #T_6c2c2_row14_col0, #T_6c2c2_row16_col0, #T_6c2c2_row23_col0, #T_6c2c2_row23_col2 {
#   background-color: #fffee1;
#   color: #000000;
# }
# #T_6c2c2_row7_col3, #T_6c2c2_row20_col3 {
#   background-color: #fff6b9;
#   color: #000000;
# }
# #T_6c2c2_row7_col4, #T_6c2c2_row13_col1, #T_6c2c2_row16_col2, #T_6c2c2_row21_col1, #T_6c2c2_row21_col4 {
#   background-color: #fffee0;
#   color: #000000;
# }
# #T_6c2c2_row9_col1 {
#   background-color: #fec859;
#   color: #000000;
# }
# #T_6c2c2_row9_col2, #T_6c2c2_row12_col2 {
#   background-color: #fff9c6;
#   color: #000000;
# }
# #T_6c2c2_row9_col3 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_6c2c2_row9_col4, #T_6c2c2_row17_col3 {
#   background-color: #fee79a;
#   color: #000000;
# }
# #T_6c2c2_row11_col1, #T_6c2c2_row11_col3, #T_6c2c2_row15_col1 {
#   background-color: #fff7be;
#   color: #000000;
# }
# #T_6c2c2_row11_col7 {
#   background-color: #fff6ba;
#   color: #000000;
# }
# #T_6c2c2_row12_col1, #T_6c2c2_row23_col1 {
#   background-color: #fff9c7;
#   color: #000000;
# }
# #T_6c2c2_row12_col3, #T_6c2c2_row19_col7, #T_6c2c2_row23_col7 {
#   background-color: #fff3b2;
#   color: #000000;
# }
# #T_6c2c2_row12_col7 {
#   background-color: #feeaa0;
#   color: #000000;
# }
# #T_6c2c2_row13_col3 {
#   background-color: #fed778;
#   color: #000000;
# }
# #T_6c2c2_row14_col4, #T_6c2c2_row17_col1 {
#   background-color: #fffbcf;
#   color: #000000;
# }
# #T_6c2c2_row15_col4, #T_6c2c2_row16_col3, #T_6c2c2_row23_col4 {
#   background-color: #fff9c9;
#   color: #000000;
# }
# #T_6c2c2_row15_col7 {
#   background-color: #fea937;
#   color: #000000;
# }
# #T_6c2c2_row16_col6, #T_6c2c2_row19_col2 {
#   background-color: #fff9c5;
#   color: #000000;
# }
# #T_6c2c2_row16_col7, #T_6c2c2_row18_col5 {
#   background-color: #fff8c4;
#   color: #000000;
# }
# #T_6c2c2_row18_col0 {
#   background-color: #fff2b1;
#   color: #000000;
# }
# #T_6c2c2_row18_col1 {
#   background-color: #fec857;
#   color: #000000;
# }
# #T_6c2c2_row18_col3 {
#   background-color: #fead3a;
#   color: #000000;
# }
# #T_6c2c2_row18_col4 {
#   background-color: #f3801c;
#   color: #f1f1f1;
# }
# #T_6c2c2_row19_col1 {
#   background-color: #fff1b0;
#   color: #000000;
# }
# #T_6c2c2_row19_col3 {
#   background-color: #febe4a;
#   color: #000000;
# }
# #T_6c2c2_row19_col4 {
#   background-color: #feeda6;
#   color: #000000;
# }
# #T_6c2c2_row22_col3 {
#   background-color: #fedd84;
#   color: #000000;
# }
# #T_6c2c2_row24_col3 {
#   background-color: #fedb80;
#   color: #000000;
# }
# #T_6c2c2_row24_col7 {
#   background-color: #fede86;
#   color: #000000;
# }
# #T_6c2c2_level0_col0, #T_6c2c2_level0_col1, #T_6c2c2_level0_col2, #T_6c2c2_level0_col3, #T_6c2c2_level0_col4, #T_6c2c2_level0_col5, #T_6c2c2_level0_col6, #T_6c2c2_level0_col7 {
#   writing-mode: vertical-lr;
#   transform: rotate(-180deg);
#   padding: 10px;
#   margins: 0;
#   vertical-align: baseline;
# }
# </style>
# <table id="T_6c2c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c2c2_level0_col0" class="col_heading level0 col0" >agriculture</th>
#       <th id="T_6c2c2_level0_col1" class="col_heading level0 col1" >alimentation et boissons</th>
#       <th id="T_6c2c2_level0_col2" class="col_heading level0 col2" >eaux usées</th>
#       <th id="T_6c2c2_level0_col3" class="col_heading level0 col3" >fragments de plastique</th>
#       <th id="T_6c2c2_level0_col4" class="col_heading level0 col4" >infrastructures</th>

# %% [markdown]
# ## Lieux d'enquêtes

# %%
survey_locations = lac_riv[["slug", "city", "zone"]].drop_duplicates()
survey_locations.set_index("slug", inplace=True)
survey_locations.index.name = None
survey_locations.style.set_table_styles(table_large_font)
# Out:
# <style type="text/css">
# #T_82897 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_82897 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_82897 tr {
#   font-size: 14px;
# }
# #T_82897 th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_82897 caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# </style>
# <table id="T_82897">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82897_level0_col0" class="col_heading level0 col0" >city</th>
#       <th id="T_82897_level0_col1" class="col_heading level0 col1" >zone</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82897_level0_row0" class="row_heading level0 row0" >aubonne</th>
#       <td id="T_82897_row0_col0" class="data row0 col0" >Aubonne</td>
#       <td id="T_82897_row0_col1" class="data row0 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row1" class="row_heading level0 row1" >baby-plage</th>
#       <td id="T_82897_row1_col0" class="data row1 col0" >Genève</td>
#       <td id="T_82897_row1_col1" class="data row1 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row2" class="row_heading level0 row2" >bouveret</th>
#       <td id="T_82897_row2_col0" class="data row2 col0" >Bouveret</td>
#       <td id="T_82897_row2_col1" class="data row2 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row3" class="row_heading level0 row3" >clarens</th>
#       <td id="T_82897_row3_col0" class="data row3 col0" >Clarens</td>
#       <td id="T_82897_row3_col1" class="data row3 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row4" class="row_heading level0 row4" >crans</th>
#       <td id="T_82897_row4_col0" class="data row4 col0" >Crans</td>
#       <td id="T_82897_row4_col1" class="data row4 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row5" class="row_heading level0 row5" >cully-p</th>
#       <td id="T_82897_row5_col0" class="data row5 col0" >Cully</td>
#       <td id="T_82897_row5_col1" class="data row5 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row6" class="row_heading level0 row6" >gland</th>
#       <td id="T_82897_row6_col0" class="data row6 col0" >Gland</td>
#       <td id="T_82897_row6_col1" class="data row6 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row7" class="row_heading level0 row7" >grangettes</th>
#       <td id="T_82897_row7_col0" class="data row7 col0" >Grangettes</td>
#       <td id="T_82897_row7_col1" class="data row7 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row8" class="row_heading level0 row8" >hermance</th>
#       <td id="T_82897_row8_col0" class="data row8 col0" >Hermance</td>
#       <td id="T_82897_row8_col1" class="data row8 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row9" class="row_heading level0 row9" >lutry</th>
#       <td id="T_82897_row9_col0" class="data row9 col0" >Lutry</td>
#       <td id="T_82897_row9_col1" class="data row9 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row10" class="row_heading level0 row10" >maladaire</th>
#       <td id="T_82897_row10_col0" class="data row10 col0" >La Tour-de-Peilz</td>
#       <td id="T_82897_row10_col1" class="data row10 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row11" class="row_heading level0 row11" >parc-des-pierrettes</th>
#       <td id="T_82897_row11_col0" class="data row11 col0" >Saint-Sulpice (VD)</td>
#       <td id="T_82897_row11_col1" class="data row11 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row12" class="row_heading level0 row12" >pichette</th>
#       <td id="T_82897_row12_col0" class="data row12 col0" >Vevey</td>
#       <td id="T_82897_row12_col1" class="data row12 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row13" class="row_heading level0 row13" >plage-de-st-sulpice</th>
#       <td id="T_82897_row13_col0" class="data row13 col0" >Saint-Sulpice (VD)</td>
#       <td id="T_82897_row13_col1" class="data row13 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row14" class="row_heading level0 row14" >port-choiseul</th>
#       <td id="T_82897_row14_col0" class="data row14 col0" >Versoix</td>
#       <td id="T_82897_row14_col1" class="data row14 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row15" class="row_heading level0 row15" >preverenges-p</th>
#       <td id="T_82897_row15_col0" class="data row15 col0" >Préverenges</td>
#       <td id="T_82897_row15_col1" class="data row15 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row16" class="row_heading level0 row16" >rolle</th>
#       <td id="T_82897_row16_col0" class="data row16 col0" >Rolle</td>
#       <td id="T_82897_row16_col1" class="data row16 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row17" class="row_heading level0 row17" >savoniere</th>
#       <td id="T_82897_row17_col0" class="data row17 col0" >Savonière</td>
#       <td id="T_82897_row17_col1" class="data row17 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row18" class="row_heading level0 row18" >tiger-duck-beach</th>
#       <td id="T_82897_row18_col0" class="data row18 col0" >Saint-Sulpice (VD)</td>
#       <td id="T_82897_row18_col1" class="data row18 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row19" class="row_heading level0 row19" >tolochenaz-p</th>
#       <td id="T_82897_row19_col0" class="data row19 col0" >Tolochenaz</td>
#       <td id="T_82897_row19_col1" class="data row19 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row20" class="row_heading level0 row20" >versoix-p</th>
#       <td id="T_82897_row20_col0" class="data row20 col0" >Versoix</td>
#       <td id="T_82897_row20_col1" class="data row20 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row21" class="row_heading level0 row21" >vidy-p</th>
#       <td id="T_82897_row21_col0" class="data row21 col0" >Vidy</td>
#       <td id="T_82897_row21_col1" class="data row21 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row22" class="row_heading level0 row22" >villa-barton</th>
#       <td id="T_82897_row22_col0" class="data row22 col0" >Genève</td>
#       <td id="T_82897_row22_col1" class="data row22 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row23" class="row_heading level0 row23" >anarchy-beach</th>
#       <td id="T_82897_row23_col0" class="data row23 col0" >La Tour-de-Peilz</td>
#       <td id="T_82897_row23_col1" class="data row23 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row24" class="row_heading level0 row24" >arabie</th>
#       <td id="T_82897_row24_col0" class="data row24 col0" >Vevey</td>
#       <td id="T_82897_row24_col1" class="data row24 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row25" class="row_heading level0 row25" >baby-plage-geneva</th>
#       <td id="T_82897_row25_col0" class="data row25 col0" >Genève</td>
#       <td id="T_82897_row25_col1" class="data row25 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row26" class="row_heading level0 row26" >baby-plage-ii-geneve</th>
#       <td id="T_82897_row26_col0" class="data row26 col0" >Genève</td>
#       <td id="T_82897_row26_col1" class="data row26 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row27" class="row_heading level0 row27" >bain-des-dames</th>
#       <td id="T_82897_row27_col0" class="data row27 col0" >La Tour-de-Peilz</td>
#       <td id="T_82897_row27_col1" class="data row27 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row28" class="row_heading level0 row28" >baye-de-clarens</th>
#       <td id="T_82897_row28_col0" class="data row28 col0" >Montreux</td>
#       <td id="T_82897_row28_col1" class="data row28 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_82897_level0_row29" class="row_heading level0 row29" >baye-de-montreux-d</th>
#       <td id="T_82897_row29_col0" class="data row29 col0" >Montreux</td>
#       <td id="T_82897_row29_col1" class

# %% [markdown]
# ## Inventaire complet

# %%
operators = {
    "quantity":"sum",
    "pcs/m": "median",
}

lac_riv["fail"] = lac_riv["quantity"] > 0
code_fails = lac_riv.groupby("code").fail.sum()
code_fail_rate = code_fails/lac_riv.loc_date.nunique()


inventory = lac_riv.groupby("code", as_index=False).agg(operators)

# %%
inventory["fail_rate"] = inventory.code.apply(lambda x: code_fail_rate.loc[x])
inventory = inventory[inventory.quantity > 0]
inventory["object"] =inventory.code.apply(lambda x: french_names[x])
inventory = inventory[["code", "object", "quantity", "pcs/m", "fail_rate"]]
inventory.set_index("code", inplace=True)
inventory["quantity"] = inventory.quantity.astype("int")

inventory.sort_values(by="quantity", inplace=True, ascending=False)
inventory.rename(columns=display_names, inplace=True)
inventory.index.name = None

# %%
inventory.style.set_table_styles(table_large_font).format(precision=3)
# Out:
# <style type="text/css">
# #T_40129 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_40129 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_40129 tr {
#   font-size: 14px;
# }
# #T_40129 th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_40129 caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# </style>
# <table id="T_40129">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40129_level0_col0" class="col_heading level0 col0" >object</th>
#       <th id="T_40129_level0_col1" class="col_heading level0 col1" >quantité</th>
#       <th id="T_40129_level0_col2" class="col_heading level0 col2" >pcs/m</th>
#       <th id="T_40129_level0_col3" class="col_heading level0 col3" >fail_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40129_level0_row0" class="row_heading level0 row0" >Gfrags</th>
#       <td id="T_40129_row0_col0" class="data row0 col0" >Plastiques fragmentés</td>
#       <td id="T_40129_row0_col1" class="data row0 col1" >17235</td>
#       <td id="T_40129_row0_col2" class="data row0 col2" >0.560</td>
#       <td id="T_40129_row0_col3" class="data row0 col3" >0.940</td>
#     </tr>
#     <tr>
#       <th id="T_40129_level0_row1" class="row_heading level0 row1" >G27</th>
#       <td id="T_40129_row1_col0" class="data row1 col0" >Mégots et filtres à cigarettes</td>
#       <td id="T_40129_row1_col1" class="data row1 col1" >16342</td>
#       <td id="T_40129_row1_col2" class="data row1 col2" >0.510</td>
#       <td id="T_40129_row1_col3" class="data row1 col3" >0.865</td>
#     </tr>
#     <tr>
#       <th id="T_40129_level0_row2" class="row_heading level0 row2" >Gfoam</th>
#       <td id="T_40129_row2_col0" class="data row2 col0" >Polystyrène expansé fragmenté</td>
#       <td id="T_40129_row2_col1" class="data row2 col1" >12296</td>
#       <td id="T_40129_row2_col2" class="data row2 col2" >0.240</td>
#       <td id="T_40129_row2_col3" class="data row2 col3" >0.818</td>
#     </tr>
#     <tr>
#       <th id="T_40129_level0_row3" class="row_heading level0 row3" >G30</th>
#       <td id="T_40129_row3_col0" class="data row3 col0" >Emballages de bonbons, de snacks</td>
#       <td id="T_40129_row3_col1" class="data row3 col1" >6686</td>
#       <td id="T_40129_row3_col2" class="data row3 col2" >0.214</td>
#       <td id="T_40129_row3_col3" class="data row3 col3" >0.887</td>
#     </tr>
#     <tr>
#       <th id="T_40129_level0_row4" class="row_heading level0 row4" >G95</th>
#       <td id="T_40129_row4_col0" class="data row4 col0" >Coton-tige</td>
#       <td id="T_40129_row4_col1" class="data row4 col1" >4774</td>
#       <td id="T_40129_row4_col2" class="data row4 col2" >0.140</td>
#       <td id="T_40129_row4_col3" class="data row4 col3" >0.777</td>
#     </tr>
#     <tr>
#       <th id="T_40129_level0_row5" class="row_heading level0 row5" >Gcaps</th>
#       <td id="T_40129_row5_col0" class="data row5 col0" >Couvercles de bouteilles en plastique</td>
#       <td id="T_40129_row5_col1" class="data row5 col1" >3904</td>
#       <td id="T_40129_row5_col2" class="data row5 col2" >0.130</td>
#       <td id="T_40129_row5_col3" class="data row5 col3" >0.853</td>
#     </tr>
#     <tr>
#       <th id="T_40129_level0_row6" class="row_heading level0 row6" >G67</th>
#       <td id="T_40129_row6_col0" class="data row6 col0" >Bâche, feuille plastique industrielle</td>
#       <td id="T_40129_row6_col1" class="data row6 col1" >3227</td>
#       <td id="T_40129_row6_col2" class="data row6 col2" >0.060</td>
#       <td id="T_40129_row6_col3" class="data row6 col3" >0.583</td>
#     </tr>
#     <tr>
#       <th id="T_40129_level0_row7" class="row_heading level0 row7" >G112</th>
#       <td id="T_40129_row7_col0" class="data row7 col0" >Pellets industriels (GPI)</td>
#       <td id="T_40129_row7_col1" class="data row7 col1" >2686</td>
#       <td id="T_40129_row7_col2" class="data row7 col2" >0.000</td>
#       <td id="T_40129_row7_col3" class="data row7 col3" >0.232</td>
#     </tr>
#     <tr>
#       <th id="T_40129_level0_row8" class="row_heading level0 row8" >G70</th>
#       <td id="T_40129_row8_col0" class="data row8 col0" >Cartouches de fusil de chasse</td>
#       <td id="T_40129_row8_col1" class="data row8 col1" >1028</td>
#       <td id="T_40129_row8_col2" class="data row8 col2" >0.010</td>
#       <td id="T_40129_row8_col3" class="data row8 col3" >0.495</td>
#     </tr>
#     <tr>
#       <th id="T_40129_level0_row9" class="row_heading level0 row9" >G10</th>
#       <td id="T_40129_row9_col0" class="data row9 col0" >Emballage fast food</td>
#       <td id="T_40129_row9_col1" class="data row9 col1" >623</td>
#       <td id="T_40129_row9_col2" class="data row9 col2" >0.000</td>
#       <td id="T_40129_row9_col3" class="data row9 col3" >0.373</td>
#     </tr>
#   </tbody>
# </table>

# %%
today = dt.datetime.now().date().strftime("%d/%m/%Y")
where = "Biel, CH"

my_block = f"""
<br />
<br />
This script updated {today} in {where}

\u2764\ufe0f what you do - faites ce que vous \u2764\ufe0f
"""

md(my_block)
# Out:
# <br />
# <br />
# This script updated 11/09/2023 in Biel, CH
#
# ❤️ what you do - faites ce que vous ❤️

# %%
# %watermark --iversions -b -r
# Out:
# Git repo: https://github.com/hammerdirt-analyst/cantonal_reports.git
#
# Git branch: main
#
# seaborn   : 0.12.2
# numpy     : 1.25.2
# json      : 2.0.9
# pandas    : 2.0.3
# matplotlib: 3.7.1
