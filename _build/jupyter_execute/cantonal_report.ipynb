# %%
# %load_ext watermark
import pandas as pd
import numpy as np
import datetime as dt
from IPython.display import Markdown as md
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import seaborn as sns
import json

# this defines the css rules for the note-book table displays
header_row = {'selector': 'th:nth-child(1)', 'props': f'background-color: #FFF; text-align:right'}
even_rows = {"selector": 'tr:nth-child(even)', 'props': f'background-color: rgba(139, 69, 19, 0.08);'}
odd_rows = {'selector': 'tr:nth-child(odd)', 'props': 'background: #FFF;'}
table_font = {'selector': 'tr', 'props': 'font-size: 10px;'}
table_data = {'selector': 'td', 'props': 'padding: 6px;'}
table_caption = {'selector': 'caption', 'props': 'font-size: 14px; font-style: italic; caption-side: bottom; text-align: left; margin-top: 10px'}
table_css_styles = [even_rows, odd_rows, table_font, header_row, table_caption]

table_large_data = {'selector': 'tr', 'props': 'font-size: 14px;'}
table_large_font = [even_rows, odd_rows, table_large_data, header_row, table_caption]

def rotateText(x):
    return 'writing-mode: vertical-lr; transform: rotate(-180deg);  padding:10px; margins:0; vertical-align: baseline;'

canton = "Valais"
cantons_avoisinante = "Vaud, Genève"

# land use
land_use = pd.read_csv("resources/work_land_use.csv")
lu_map = land_use[land_use.use == "Siedl"][["slug", "scaled"]].set_index("slug")

all_data = pd.read_csv("resources/survey_work_data.csv", low_memory=False)
all_data["Project"] = all_data.Project.where(all_data.Project == "training", "training")
all_data = all_data[['loc_date', 'slug', 'city', 'water_name_slug', 'date', 'doy', 'Project', 'code', 'pcs/m', 'quantity', 'canton', 'zone']].copy()
all_data["date"] = pd.to_datetime(all_data["date"])
all_data = all_data[all_data.code != "G216"]

# %%
codes_of_interest = [
    "G95",
    "G70",
    "Gfrags",
    "Gfoam",
    "G112",
    "G27",
    "G30",
    "G67",
    "G10",
    "Gcaps",
]

all_data = all_data[all_data.code.isin(codes_of_interest)].copy()

lake_and_river_values = (all_data.Project == "training")&(all_data.canton == canton)
mountain_values = (all_data.zone == "montagne")&(all_data.canton == canton)
valais_all =  pd.concat([all_data[lake_and_river_values], all_data[mountain_values]])

valais_all.drop_duplicates(["code", "loc_date"], inplace=True)

not_valais = all_data[all_data.canton != canton].copy()
not_valais = not_valais[not_valais["date"] <= "2021-10-31"].copy()
# not_valais["date"] = pd.to_datetime(not_valais["date"])
operations={
    "loc_date":"nunique", 
    "city":"nunique", 
    "quantity":"sum",
    "slug":"nunique"
}
summary_data = valais_all.groupby(["zone"]).agg(operations)

summary_data = summary_data.astype("int")

# %% [markdown]
# # Valais

# %% [markdown]
# ## Historique
#
# Le Valais dispose d'une côte réduite au lac Léman. C'est pourquoi, par rapport aux autres cantons riverains du lac, il y a relativement peu d'échantillons. Le premier échantillon valaisan a été prélevé à Saint-Gingolph en 2016. La masse d'échantillons décrivant les conditions valaisannes a été collectée dans le cadre du recensement fédéral des déchets sauvages. Cette publication présente les résultats pour le lac ([Le Léman](https://hammerdirt-analyst.github.io/IQAASL-End-0f-Sampling-2021/lac-leman.html)) et le Rhône ([Rhône](https://hammerdirt-analyst.github.io/IQAASL-End-0f-Sampling-2021/rhone_sa.html#)). Les résultats des Alpes ont été considérés séparément ([Alpen und der Jura](https://hammerdirt-analyst.github.io/IQAASL-End-0f-Sampling-2021/alpes_valaisannes.html)).
#
# Nous considérons ici les résultats comme des zones d'intérêt pour les acteurs du canton. Nous définissons donc trois zones qui représentent les différentes régions où des données ont été collectées dans le canton.
#
# * lac
# * montagne
# * rivière
#
# ### Definitions/abbreviations
#
# 1. pcs/m: nombre de déchets pour un mètre de littoral ou sentier pédestre
# 2. quantité: le nombre de déchets identifier
# 3. échantillons/inventaire: L'action de ramasser les déchets et de les compter à un endroit donné.
# 4. utilsation du sols: Cela correspond aux couches cartographiques disponibles sur swiss GeoAdmin.
# 5. taux d'échec: Rapport entre le nombre de fois où un objet spécifique a été trouvé et le nombre total d'échantillons. Un peu comme la fréquence.
#
# ### Résumé des échantillons novembre 2015 à novembre 2021
#
# Au total, 24 échantillons ont été prélevés en Valais. Cela représente 10'316 objets collectés sur 4'152 m².

# %%
caption_english = "Sampling history Valais: The number of samples and the magnitude of the effort by context. Note: hours is the amount of time counting and collecting."

caption_french = "Historique des échantillonnages Valais : Le nombre d'échantillons et l'ampleur de l'effort par contexte. Remarque : les heures correspondent au temps passé à compter et à collecter."

# %%
dims = pd.read_csv("resources/work_dimensions.csv")

def save_json(filename, data):
    with open(f"resources/{filename}", "w") as afile:
        json.dump(data, afile)

def open_json(filename):
    with open(f"resources/{filename}", "r") as afile:
        data = json.load(afile)
        return data
    

display_names = open_json("french_display_names.json")

land_use_names = open_json("french_land_use_names.json")

material_names = open_json("french_material_names.json")

group_names = open_json("french_group_names.json")

french_names = open_json("french_code_translations.json")

land_use_of_interest = [
    'Siedl', 
    'Wald',
    'Stadtzentr',
    'Reben', 
    'Obstanlage',
    'undefined',
    'infrastructure',
    'recreation',
    'Strasse'
]


def dimensional_summary(dims, survey_data, zones=["lac", "rivière", "montagne"]):
    dfs = []
    for label in zones:
        d_f = dims[dims.slug.isin(valais_all[valais_all.zone == label].slug.unique())].copy()
        d_f["zone"] = label
        dfs.append(d_f)
    dimensions = pd.concat(dfs)
    d_sum = dimensions.groupby("zone").agg({"area":"sum", "length":"sum", "time":"sum"})
    return dimensions, d_sum

dimensional_summary, d_sum = dimensional_summary(dims, valais_all, zones=["lac", "rivière", "montagne"])

summary_by_zone = pd.concat([summary_data, d_sum], axis=1, ignore_index=False)
summary_by_zone["hours"] = (summary_by_zone["time"]/60).round(2)
summary_by_zone.drop("time", inplace=True, axis=1)
summary_by_zone.loc["total", : ] = summary_by_zone.sum()

# %%
summary_by_zone.index.name = None
summary_by_zone.rename(columns=display_names, inplace=True)
summary_by_zone = summary_by_zone.astype("int")
summary_by_zone.style.set_table_styles(table_large_font).format('{:,}' ).set_caption(caption_french)
# Out:
# <style type="text/css">
# #T_13bbb tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_13bbb tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_13bbb tr {
#   font-size: 14px;
# }
# #T_13bbb th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_13bbb caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# </style>
# <table id="T_13bbb">
#   <caption>Historique des échantillonnages Valais : Le nombre d'échantillons et l'ampleur de l'effort par contexte. Remarque : les heures correspondent au temps passé à compter et à collecter.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13bbb_level0_col0" class="col_heading level0 col0" >échantillons</th>
#       <th id="T_13bbb_level0_col1" class="col_heading level0 col1" >municipalités</th>
#       <th id="T_13bbb_level0_col2" class="col_heading level0 col2" >quantité</th>
#       <th id="T_13bbb_level0_col3" class="col_heading level0 col3" >site</th>
#       <th id="T_13bbb_level0_col4" class="col_heading level0 col4" >m²</th>
#       <th id="T_13bbb_level0_col5" class="col_heading level0 col5" >mètres</th>
#       <th id="T_13bbb_level0_col6" class="col_heading level0 col6" >heures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13bbb_level0_row0" class="row_heading level0 row0" >lac</th>
#       <td id="T_13bbb_row0_col0" class="data row0 col0" >17</td>
#       <td id="T_13bbb_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_13bbb_row0_col2" class="data row0 col2" >8,367</td>
#       <td id="T_13bbb_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_13bbb_row0_col4" class="data row0 col4" >4,718</td>
#       <td id="T_13bbb_row0_col5" class="data row0 col5" >1,794</td>
#       <td id="T_13bbb_row0_col6" class="data row0 col6" >74</td>
#     </tr>
#     <tr>
#       <th id="T_13bbb_level0_row1" class="row_heading level0 row1" >montagne</th>
#       <td id="T_13bbb_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_13bbb_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_13bbb_row1_col2" class="data row1 col2" >350</td>
#       <td id="T_13bbb_row1_col3" class="data row1 col3" >7</td>
#       <td id="T_13bbb_row1_col4" class="data row1 col4" >1,837</td>
#       <td id="T_13bbb_row1_col5" class="data row1 col5" >436</td>
#       <td id="T_13bbb_row1_col6" class="data row1 col6" >24</td>
#     </tr>
#     <tr>
#       <th id="T_13bbb_level0_row2" class="row_heading level0 row2" >rivière</th>
#       <td id="T_13bbb_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_13bbb_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_13bbb_row2_col2" class="data row2 col2" >26</td>
#       <td id="T_13bbb_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_13bbb_row2_col4" class="data row2 col4" >480</td>
#       <td id="T_13bbb_row2_col5" class="data row2 col5" >181</td>
#       <td id="T_13bbb_row2_col6" class="data row2 col6" >5</td>
#     </tr>
#     <tr>
#       <th id="T_13bbb_level0_row3" class="row_heading level0 row3" >total</th>
#       <td id="T_13bbb_row3_col0" class="data row3 col0" >28</td>
#       <td id="T_13bbb_row3_col1" class="data row3 col1" >13</td>
#       <td id="T_13bbb_row3_col2" class="data row3 col2" >8,743</td>
#       <td id="T_13bbb_row3_col3" class="data row3 col3" >13</td>
#       <td id="T_13bbb_row3_col4" class="data row3 col4" >7,035</td>
#       <td id="T_13bbb_row3_col5" class="data row3 col5" >2,411</td>
#       <td id="T_13bbb_row3_col6" class="data row3 col6" >103</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Communes et zones d'intérêt

# %%
cities_in_canton = ', '.join(valais_all.city.unique())

munix = f'__Municipalités:__ {cities_in_canton}'
md(munix)
# Out:
# __Municipalités:__ Riddes, Sion, Leuk, Salgesch, Bouveret, Saint-Gingolph, Val-de-Charmey, Crans-Montana, Val-d'Illiez, Troistorrents, Nendaz, Val de Bagnes

# %%
lakes = ', '.join(valais_all[valais_all.zone == 'lac'].water_name_slug.unique())
lakex = f'__Lacs:__ {lakes}'
md(lakex)
# Out:
# __Lacs:__ lac-leman

# %%
rivers = ', '.join(valais_all[valais_all.zone == 'rivière'].water_name_slug.unique())
riverx = f'__Rivières:__ {rivers}'
md(riverx)
# Out:
# __Rivières:__ rhone

# %% [markdown]
# ### Utilisation des sols
#
# L'utilisation du sol des sites étudiés en Valais par rapport à l'utilisation du sol d'autres cantons sur le lac.
#
# Chaque lieu d'inventaire est géolocalisé au centre d'un hexagone de 3 000 mètres. L'ampleur des attributs de l'occupation et de l'utilisation des sols à l'intérieur de cet hexagone est calculée. Cette procédure peut améliorer le choix des lieux d'échantillonnage. Les résultats ont déjà été utilisés pour identifier les caractéristiques d'un lieu d'inventaire qui peuvent conduire à l'accumulation de certains déchets.

# %%
fig, axs = plt.subplots(2, 5, figsize=(7,6), sharey=True)

valais_locs = valais_all.slug.unique()
region_locs = all_data[all_data.canton.isin(["Vaud", "Genève"])].slug.unique()

index_order = [
    'Siedl',
    'infrastructure', 
    'Wald',
    'Obstanlage',
    'Undefined',
    'recreation',
    'Reben',
    'Stadtzentr',
  
]

ax_s = {
    'Siedl':[0,0],
    'infrastructure':[0,1], 
    'Wald':[0,2],
    'Obstanlage':[0,3],
    'undefined':[0,4],
    'recreation':[1,0],
    'Reben':[1,1],
    'Stadtzentr':[1,2],
}

l_used = land_use[land_use.use.isin(land_use_of_interest)]
v_land_use = land_use[land_use.slug.isin(valais_locs)].copy()
r_land_use = land_use[land_use.slug.isin(region_locs)].copy()

no_streets = [x for x in land_use_of_interest if x != "Strasse"]

for i, name in enumerate(ax_s.keys()):
    
    row = ax_s[name][0]
    column = ax_s[name][1]
    ax = axs[row, column]
    sns.stripplot(data = v_land_use[v_land_use.use == name], y = "scaled", color="magenta", zorder=20, size=6, ax=ax)
    sns.boxplot(data= r_land_use[r_land_use.use == name], y="scaled",  ax=ax, color='slategray')
    ax.set_xticks([0], [land_use_names[name]])
    ax.set_ylabel("proportion")

axs[1, 4].axis('off')
a_space = axs[1, 3]
a_space.axis('off')
h = [ Line2D([0], [0], marker='o', color='w', label='Scatter', markerfacecolor='magenta', markersize=10), Patch(facecolor='slategray', edgecolor='black', label='Color Patch')]
l = [canton, cantons_avoisinante ]
a_space.legend(h,l, bbox_to_anchor=(0,1), loc="upper left")

plt.tight_layout()
plt.subplots_adjust(wspace=.1)
plt.show()

# %% [markdown]
# ## Résultats des inventaires
#
# La densité est calculée en additionnant tous les objets trouvés pour chaque jour et lieu d'échantillonnage. La somme pour chaque échantillon est ensuite divisée par la longueur du rivage, de la rive ou du tronçon de sentier. Pour un exemple, voir le rapport fédéral sur le calcul des lignes de base. [Baselines](https://hammerdirt-analyst.github.io/IQAASL-End-0f-Sampling-2021/baselines.html).

# %%
# # make the survey total from the list of available codes
# # survey_totals from valais
vs_jt = valais_all.groupby(["loc_date", "date", "zone"], as_index=False)["pcs/m"].sum()

# all other locations
# lake
lake_jt=not_valais[not_valais.zone == "lac"].groupby(["loc_date", "date"], as_index=False)["pcs/m"].sum()

# rivers
rhn_jt = not_valais[not_valais.zone == "rivière"].groupby(["loc_date", "date"], as_index=False)["pcs/m"].sum()

#alpes
alp_jt = not_valais[not_valais.zone == "montagne"].groupby(["loc_date", "date"], as_index=False)["pcs/m"].sum()

french_caption = "La densité totale par échantillon pour les 74 objets d'intérêt. \
Le premier prélèvement en Valais date de 2016. Les prélèvements en rivière \
et en montagne ont été réalisés lors du rapport fédéral."

fig, ax = plt.subplots()
sns.scatterplot(data=vs_jt, x="date", y="pcs/m", hue="zone", zorder=20, palette={'lac':'royalblue', 'montagne':'saddlebrown', 'rivière': 'black'}, ax=ax)
sns.scatterplot(data=lake_jt,  x="date", y="pcs/m", zorder=0, color='royalblue', alpha=0.2, ax=ax, label='Le Léman')
sns.scatterplot(data=rhn_jt, x="date", y="pcs/m", zorder=1, color='slategray', alpha=0.2, ax=ax, label='Autres rivières')
sns.scatterplot(data=alp_jt, x="date", y="pcs/m", zorder=1, color='saddlebrown', alpha=0.2, ax=ax, label='Les Alpes')
ax.set_ylim(-1, 60)
ax.legend(bbox_to_anchor=(0, 1), loc="upper left", ncol=2)
ax.set_xlabel("")
plt.show()

# %% [markdown]
# ### Répartition de la densité des déchets
#
# __Répartition de la densité des déchets à l'intérieur du canton.__

# %%
summaries = {
    canton:vs_jt["pcs/m"].describe(),
    "Le Léman": lake_jt["pcs/m"].describe(),
    "Autres Rivières":rhn_jt["pcs/m"].describe(),
    "Alpes": alp_jt["pcs/m"].describe()
    
}

zone_summaries = {
    "Lac":vs_jt[vs_jt.zone == "lac"]["pcs/m"].describe(),
    "Montagne":vs_jt[vs_jt.zone == "montagne"]["pcs/m"].describe(),
    "Rhône":vs_jt[vs_jt.zone == "rivière"]["pcs/m"].describe(),
    canton:vs_jt["pcs/m"].describe(),
}

valais_pcsm_total = pd.DataFrame(zone_summaries)
valais_pcsm_total = valais_pcsm_total.T
valais_pcsm_total["count"] = valais_pcsm_total["count"].astype("int")
valais_pcsm_total.rename(columns=display_names, inplace=True)
valais_pcsm_total.drop("echantillons", inplace=True, axis=1)
valais_pcsm_total = valais_pcsm_total.T

english_caption_2 = "La répartition de la densité de déchets en Valais selon le domaine d'étude."

dis_total = valais_pcsm_total.style.set_table_styles(table_large_font).format(precision=2).set_caption(english_caption_2)
dis_total.background_gradient(axis=None, vmin=valais_pcsm_total.min().min(), vmax=valais_pcsm_total.max().max(), cmap="YlOrBr")
# Out:
# <style type="text/css">
# #T_dbbb2 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_dbbb2 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_dbbb2 tr {
#   font-size: 14px;
# }
# #T_dbbb2 th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_dbbb2 caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# #T_dbbb2_row0_col0 {
#   background-color: #febe4a;
#   color: #000000;
# }
# #T_dbbb2_row0_col1, #T_dbbb2_row1_col1 {
#   background-color: #fffddc;
#   color: #000000;
# }
# #T_dbbb2_row0_col2, #T_dbbb2_row2_col1, #T_dbbb2_row2_col2, #T_dbbb2_row2_col3, #T_dbbb2_row3_col2, #T_dbbb2_row4_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_dbbb2_row0_col3 {
#   background-color: #fee493;
#   color: #000000;
# }
# #T_dbbb2_row1_col0 {
#   background-color: #fed069;
#   color: #000000;
# }
# #T_dbbb2_row1_col2, #T_dbbb2_row5_col2 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_dbbb2_row1_col3, #T_dbbb2_row5_col3 {
#   background-color: #fed471;
#   color: #000000;
# }
# #T_dbbb2_row2_col0, #T_dbbb2_row5_col1 {
#   background-color: #fffcd7;
#   color: #000000;
# }
# #T_dbbb2_row3_col0 {
#   background-color: #fff3b4;
#   color: #000000;
# }
# #T_dbbb2_row3_col1, #T_dbbb2_row6_col2 {
#   background-color: #fffee2;
#   color: #000000;
# }
# #T_dbbb2_row3_col3 {
#   background-color: #fffee1;
#   color: #000000;
# }
# #T_dbbb2_row4_col0 {
#   background-color: #fed778;
#   color: #000000;
# }
# #T_dbbb2_row4_col1 {
#   background-color: #fffee0;
#   color: #000000;
# }
# #T_dbbb2_row4_col3 {
#   background-color: #fff7bc;
#   color: #000000;
# }
# #T_dbbb2_row5_col0 {
#   background-color: #fea433;
#   color: #000000;
# }
# #T_dbbb2_row6_col0, #T_dbbb2_row6_col3 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_dbbb2_row6_col1 {
#   background-color: #fffacd;
#   color: #000000;
# }
# </style>
# <table id="T_dbbb2">
#   <caption>La répartition de la densité de déchets en Valais selon le domaine d'étude.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbbb2_level0_col0" class="col_heading level0 col0" >Lac</th>
#       <th id="T_dbbb2_level0_col1" class="col_heading level0 col1" >Montagne</th>
#       <th id="T_dbbb2_level0_col2" class="col_heading level0 col2" >Rhône</th>
#       <th id="T_dbbb2_level0_col3" class="col_heading level0 col3" >Valais</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbbb2_level0_row0" class="row_heading level0 row0" >moyenne</th>
#       <td id="T_dbbb2_row0_col0" class="data row0 col0" >13.63</td>
#       <td id="T_dbbb2_row0_col1" class="data row0 col1" >1.02</td>
#       <td id="T_dbbb2_row0_col2" class="data row0 col2" >0.13</td>
#       <td id="T_dbbb2_row0_col3" class="data row0 col3" >8.55</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb2_level0_row1" class="row_heading level0 row1" >écart-type</th>
#       <td id="T_dbbb2_row1_col0" class="data row1 col0" >11.34</td>
#       <td id="T_dbbb2_row1_col1" class="data row1 col1" >1.01</td>
#       <td id="T_dbbb2_row1_col2" class="data row1 col2" >0.17</td>
#       <td id="T_dbbb2_row1_col3" class="data row1 col3" >10.86</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb2_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_dbbb2_row2_col0" class="data row2 col0" >1.57</td>
#       <td id="T_dbbb2_row2_col1" class="data row2 col1" >0.07</td>
#       <td id="T_dbbb2_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_dbbb2_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb2_level0_row3" class="row_heading level0 row3" >25%</th>
#       <td id="T_dbbb2_row3_col0" class="data row3 col0" >5.28</td>
#       <td id="T_dbbb2_row3_col1" class="data row3 col1" >0.37</td>
#       <td id="T_dbbb2_row3_col2" class="data row3 col2" >0.04</td>
#       <td id="T_dbbb2_row3_col3" class="data row3 col3" >0.54</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb2_level0_row4" class="row_heading level0 row4" >50%</th>
#       <td id="T_dbbb2_row4_col0" class="data row4 col0" >10.39</td>
#       <td id="T_dbbb2_row4_col1" class="data row4 col1" >0.58</td>
#       <td id="T_dbbb2_row4_col2" class="data row4 col2" >0.07</td>
#       <td id="T_dbbb2_row4_col3" class="data row4 col3" >4.49</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb2_level0_row5" class="row_heading level0 row5" >75%</th>
#       <td id="T_dbbb2_row5_col0" class="data row5 col0" >16.22</td>
#       <td id="T_dbbb2_row5_col1" class="data row5 col1" >1.54</td>
#       <td id="T_dbbb2_row5_col2" class="data row5 col2" >0.15</td>
#       <td id="T_dbbb2_row5_col3" class="data row5 col3" >10.77</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb2_level0_row6" class="row_heading level0 row6" >max</th>
#       <td id="T_dbbb2_row6_col0" class="data row6 col0" >34.85</td>
#       <td id="T_dbbb2_row6_col1" class="data row6 col1" >2.70</td>
#       <td id="T_dbbb2_row6_col2" class="data row6 col2" >0.38</td>
#       <td id="T_dbbb2_row6_col3" class="data row6 col3" >34.85</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Répartition de la densité des déchets à l'extérieur du canton.__

# %%
valais_compare = pd.DataFrame(summaries)
valais_compare = valais_compare.T
valais_compare["count"] = valais_compare["count"].astype("int")
valais_compare.rename(columns=display_names, inplace=True)
valais_compare.drop("echantillons", inplace=True, axis=1)
valais_compare = valais_compare.T

english_caption_3 = "La répartition de la densité de déchets en Valais comparé à d'autres localités ayant des domaines d'études similaires"
valais_compare.style.set_table_styles(table_large_font).format(precision=2).set_caption(english_caption_3)
dis_total = valais_compare.style.set_table_styles(table_large_font).format(precision=2).set_caption(english_caption_2)
dis_total.background_gradient(axis=None, vmin=valais_compare.min().min(), vmax=valais_compare.max().max(), cmap="YlOrBr")
# Out:
# <style type="text/css">
# #T_2e027 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_2e027 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_2e027 tr {
#   font-size: 14px;
# }
# #T_2e027 th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_2e027 caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# #T_2e027_row0_col0 {
#   background-color: #fff4b5;
#   color: #000000;
# }
# #T_2e027_row0_col1 {
#   background-color: #fff9c5;
#   color: #000000;
# }
# #T_2e027_row0_col2 {
#   background-color: #fffee1;
#   color: #000000;
# }
# #T_2e027_row0_col3 {
#   background-color: #ffface;
#   color: #000000;
# }
# #T_2e027_row1_col0, #T_2e027_row5_col0 {
#   background-color: #ffeea8;
#   color: #000000;
# }
# #T_2e027_row1_col1 {
#   background-color: #fff6ba;
#   color: #000000;
# }
# #T_2e027_row1_col2 {
#   background-color: #fffedf;
#   color: #000000;
# }
# #T_2e027_row1_col3 {
#   background-color: #fee99e;
#   color: #000000;
# }
# #T_2e027_row2_col0, #T_2e027_row2_col1, #T_2e027_row2_col2, #T_2e027_row2_col3, #T_2e027_row3_col2, #T_2e027_row3_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_2e027_row3_col0, #T_2e027_row5_col2 {
#   background-color: #fffee2;
#   color: #000000;
# }
# #T_2e027_row3_col1 {
#   background-color: #fffddc;
#   color: #000000;
# }
# #T_2e027_row4_col0 {
#   background-color: #fffacd;
#   color: #000000;
# }
# #T_2e027_row4_col1 {
#   background-color: #fffbd3;
#   color: #000000;
# }
# #T_2e027_row4_col2, #T_2e027_row4_col3 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_2e027_row5_col1 {
#   background-color: #fff8c1;
#   color: #000000;
# }
# #T_2e027_row5_col3 {
#   background-color: #fffddd;
#   color: #000000;
# }
# #T_2e027_row6_col0 {
#   background-color: #f07919;
#   color: #f1f1f1;
# }
# #T_2e027_row6_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_2e027_row6_col2 {
#   background-color: #fff9c9;
#   color: #000000;
# }
# #T_2e027_row6_col3 {
#   background-color: #cd4d03;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2e027">
#   <caption>La répartition de la densité de déchets en Valais selon le domaine d'étude.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e027_level0_col0" class="col_heading level0 col0" >Valais</th>
#       <th id="T_2e027_level0_col1" class="col_heading level0 col1" >Le Léman</th>
#       <th id="T_2e027_level0_col2" class="col_heading level0 col2" >Autres Rivières</th>
#       <th id="T_2e027_level0_col3" class="col_heading level0 col3" >Alpes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e027_level0_row0" class="row_heading level0 row0" >moyenne</th>
#       <td id="T_2e027_row0_col0" class="data row0 col0" >8.55</td>
#       <td id="T_2e027_row0_col1" class="data row0 col1" >5.71</td>
#       <td id="T_2e027_row0_col2" class="data row0 col2" >0.70</td>
#       <td id="T_2e027_row0_col3" class="data row0 col3" >4.24</td>
#     </tr>
#     <tr>
#       <th id="T_2e027_level0_row1" class="row_heading level0 row1" >écart-type</th>
#       <td id="T_2e027_row1_col0" class="data row1 col0" >10.86</td>
#       <td id="T_2e027_row1_col1" class="data row1 col1" >7.73</td>
#       <td id="T_2e027_row1_col2" class="data row1 col2" >1.31</td>
#       <td id="T_2e027_row1_col3" class="data row1 col3" >12.36</td>
#     </tr>
#     <tr>
#       <th id="T_2e027_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_2e027_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_2e027_row2_col1" class="data row2 col1" >0.02</td>
#       <td id="T_2e027_row2_col2" class="data row2 col2" >0.11</td>
#       <td id="T_2e027_row2_col3" class="data row2 col3" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_2e027_level0_row3" class="row_heading level0 row3" >25%</th>
#       <td id="T_2e027_row3_col0" class="data row3 col0" >0.54</td>
#       <td id="T_2e027_row3_col1" class="data row3 col1" >1.62</td>
#       <td id="T_2e027_row3_col2" class="data row3 col2" >0.20</td>
#       <td id="T_2e027_row3_col3" class="data row3 col3" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_2e027_level0_row4" class="row_heading level0 row4" >50%</th>
#       <td id="T_2e027_row4_col0" class="data row4 col0" >4.49</td>
#       <td id="T_2e027_row4_col1" class="data row4 col1" >3.39</td>
#       <td id="T_2e027_row4_col2" class="data row4 col2" >0.29</td>
#       <td id="T_2e027_row4_col3" class="data row4 col3" >0.28</td>
#     </tr>
#     <tr>
#       <th id="T_2e027_level0_row5" class="row_heading level0 row5" >75%</th>
#       <td id="T_2e027_row5_col0" class="data row5 col0" >10.77</td>
#       <td id="T_2e027_row5_col1" class="data row5 col1" >6.46</td>
#       <td id="T_2e027_row5_col2" class="data row5 col2" >0.59</td>
#       <td id="T_2e027_row5_col3" class="data row5 col3" >1.40</td>
#     </tr>
#     <tr>
#       <th id="T_2e027_level0_row6" class="row_heading level0 row6" >max</th>
#       <td id="T_2e027_row6_col0" class="data row6 col0" >34.85</td>
#       <td id="T_2e027_row6_col1" class="data row6 col1" >58.41</td>
#       <td id="T_2e027_row6_col2" class="data row6 col2" >5.20</td>
#       <td id="T_2e027_row6_col3" class="data row6 col3" >43.40</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Répartition des objets selon matériel.__

# %%
dfCodes = pd.read_csv("resources/codes.csv")
dfCodes.set_index("code", drop=True, inplace=True)
dfCodes.loc["Gcaps", ["material", "description", "parent_code", "groupname"]] = "Plastic", "Plastic bottle tops", "Parent code", 'food and drink'

code_d = dfCodes["description"]
code_m = dfCodes["material"]
code_g = dfCodes["groupname"]

caption_material_fr = "Total des objets par type de matériau. Tous les échantillons."

valais_all["material"] = valais_all.code.apply(lambda x: code_m.loc[x])
material_totals = valais_all.groupby("material", as_index=False).quantity.sum()
material_totals["quantity"] = material_totals.quantity.astype(int)
material_totals["material"] = material_totals.material.apply(lambda x: material_names[x])
material_totals["q_weight"] = (material_totals.quantity/material_totals.quantity.sum()).round(3)
material_totals = material_totals.set_index("material", drop=True)
material_totals.sort_values(by="quantity", ascending=False, inplace=True)
material_totals.index.name = None
material_totals.rename(columns=display_names).style.set_table_styles(table_large_font).format('{:,}').set_caption(caption_material_fr)
# Out:
# <style type="text/css">
# #T_07919 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_07919 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_07919 tr {
#   font-size: 14px;
# }
# #T_07919 th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_07919 caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# </style>
# <table id="T_07919">
#   <caption>Total des objets par type de matériau. Tous les échantillons.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07919_level0_col0" class="col_heading level0 col0" >quantité</th>
#       <th id="T_07919_level0_col1" class="col_heading level0 col1" >% de total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07919_level0_row0" class="row_heading level0 row0" >Plastique</th>
#       <td id="T_07919_row0_col0" class="data row0 col0" >8,743</td>
#       <td id="T_07919_row0_col1" class="data row0 col1" >1.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Objets d'intérêt

# %% [markdown]
# Les objets d'intérêt sont ceux qui ont été trouvés dans au moins 50 % des enquêtes ou qui figurent parmi les dix objets les plus abondants en termes de quantité.
#
# ```{note}
# Le choix du mode de regroupement des différents objets doit doivent être représentatifs des groupes cibles ou des domaines de préoccupation. Il peut y avoir de nombreux groupes différents qui sont corrects, cela dépend du cas d'utilisation. Dans le cas présent, nous nous intéressons aux objets qui ont été trouvés souvent et en grande quantité.
# ```

# %%
valais_all["fail"] = valais_all['pcs/m'] > 0
fail_rates = valais_all.groupby("code", as_index=False).fail.sum()
n_samps = valais_all.loc_date.nunique()
fail_rates["rate"]= fail_rates.fail/n_samps
fail_rates = fail_rates.sort_values(by="rate", ascending=False)
failed = fail_rates[fail_rates.rate >= .5].code.unique()

abundant = valais_all.groupby("code", as_index=False).quantity.sum()
abundant_c = abundant.sort_values(by="quantity", ascending=False)[:10].code.unique()

most_common_codes = list(set([*abundant, *failed]))

mc_data = valais_all[valais_all.code.isin(codes_of_interest)].groupby("code", as_index=False).agg({"quantity":"sum", "pcs/m":"median", "fail":"sum"})
mc_data["fail_rate"] = (mc_data.fail/n_samps).round(2)
mc_data["q_weight"] = (mc_data.quantity/abundant.quantity.sum()).round(2)
mc_data["object"] = mc_data.code.apply(lambda x: french_names[x])
mc_data = mc_data[["object", "quantity", "pcs/m", "q_weight", "fail_rate"]]

mc_data = mc_data.sort_values(by="quantity", ascending=False)
mc_data["quantity"] = mc_data.quantity.astype("int")
mc_data["pcs/m"] = mc_data["pcs/m"].round(2)
mc_data.set_index("object", drop=True, inplace=True)
mc_data.index.name = None
mc_data.rename(columns=display_names).style.set_table_styles(table_large_font).format('{:,}')
# Out:
# <style type="text/css">
# #T_f745b tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_f745b tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_f745b tr {
#   font-size: 14px;
# }
# #T_f745b th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_f745b caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# </style>
# <table id="T_f745b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f745b_level0_col0" class="col_heading level0 col0" >quantité</th>
#       <th id="T_f745b_level0_col1" class="col_heading level0 col1" >pcs/m</th>
#       <th id="T_f745b_level0_col2" class="col_heading level0 col2" >% de total</th>
#       <th id="T_f745b_level0_col3" class="col_heading level0 col3" >taux d'échec</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f745b_level0_row0" class="row_heading level0 row0" >Plastiques fragmentés</th>
#       <td id="T_f745b_row0_col0" class="data row0 col0" >2,552</td>
#       <td id="T_f745b_row0_col1" class="data row0 col1" >1.76</td>
#       <td id="T_f745b_row0_col2" class="data row0 col2" >0.29</td>
#       <td id="T_f745b_row0_col3" class="data row0 col3" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_f745b_level0_row1" class="row_heading level0 row1" >Polystyrène expansé fragmenté</th>
#       <td id="T_f745b_row1_col0" class="data row1 col0" >1,991</td>
#       <td id="T_f745b_row1_col1" class="data row1 col1" >0.51</td>
#       <td id="T_f745b_row1_col2" class="data row1 col2" >0.23</td>
#       <td id="T_f745b_row1_col3" class="data row1 col3" >0.61</td>
#     </tr>
#     <tr>
#       <th id="T_f745b_level0_row2" class="row_heading level0 row2" >Emballages de bonbons, de snacks</th>
#       <td id="T_f745b_row2_col0" class="data row2 col0" >881</td>
#       <td id="T_f745b_row2_col1" class="data row2 col1" >0.36</td>
#       <td id="T_f745b_row2_col2" class="data row2 col2" >0.1</td>
#       <td id="T_f745b_row2_col3" class="data row2 col3" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_f745b_level0_row3" class="row_heading level0 row3" >Couvercles de bouteilles en plastique</th>
#       <td id="T_f745b_row3_col0" class="data row3 col0" >766</td>
#       <td id="T_f745b_row3_col1" class="data row3 col1" >0.29</td>
#       <td id="T_f745b_row3_col2" class="data row3 col2" >0.09</td>
#       <td id="T_f745b_row3_col3" class="data row3 col3" >0.71</td>
#     </tr>
#     <tr>
#       <th id="T_f745b_level0_row4" class="row_heading level0 row4" >Coton-tige</th>
#       <td id="T_f745b_row4_col0" class="data row4 col0" >653</td>
#       <td id="T_f745b_row4_col1" class="data row4 col1" >0.19</td>
#       <td id="T_f745b_row4_col2" class="data row4 col2" >0.07</td>
#       <td id="T_f745b_row4_col3" class="data row4 col3" >0.57</td>
#     </tr>
#     <tr>
#       <th id="T_f745b_level0_row5" class="row_heading level0 row5" >Bâche, feuille plastique industrielle</th>
#       <td id="T_f745b_row5_col0" class="data row5 col0" >608</td>
#       <td id="T_f745b_row5_col1" class="data row5 col1" >0.08</td>
#       <td id="T_f745b_row5_col2" class="data row5 col2" >0.07</td>
#       <td id="T_f745b_row5_col3" class="data row5 col3" >0.57</td>
#     </tr>
#     <tr>
#       <th id="T_f745b_level0_row6" class="row_heading level0 row6" >Mégots et filtres à cigarettes</th>
#       <td id="T_f745b_row6_col0" class="data row6 col0" >455</td>
#       <td id="T_f745b_row6_col1" class="data row6 col1" >0.11</td>
#       <td id="T_f745b_row6_col2" class="data row6 col2" >0.05</td>
#       <td id="T_f745b_row6_col3" class="data row6 col3" >0.79</td>
#     </tr>
#     <tr>
#       <th id="T_f745b_level0_row7" class="row_heading level0 row7" >Pellets industriels (GPI)</th>
#       <td id="T_f745b_row7_col0" class="data row7 col0" >336</td>
#       <td id="T_f745b_row7_col1" class="data row7 col1" >0.0</td>
#       <td id="T_f745b_row7_col2" class="data row7 col2" >0.04</td>
#       <td id="T_f745b_row7_col3" class="data row7 col3" >0.39</td>
#     </tr>
#     <tr>
#       <th id="T_f745b_level0_row8" class="row_heading level0 row8" >Cartouches de fusil de chasse</th>
#       <td id="T_f745b_row8_col0" class="data row8 col0" >315</td>
#       <td id="T_f745b_row8_col1" class="data row8 col1" >0.06</td>
#       <td id="T_f745b_row8_col2" class="data row8 col2" >0.04</td>
#       <td id="T_f745b_row8_col3" class="data row8 col3" >0.64</td>
#     </tr>
#     <tr>
#       <th id="T_f745b_level0_row9" class="row_heading level0 row9" >Emballage fast food</th>
#       <td id="T_f745b_row9_col0" class="data row9 col0" >186</td>
#       <td id="T_f745b_row9_col1" class="data row9 col1" >0.03</td>
#       <td id="T_f745b_row9_col2" class="data row9 col2" >0.02</td>
#       <td id="T_f745b_row9_col3" class="data row9 col3" >0.57</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Objets d'intérêt résultats municipaux

# %%
objects_city = valais_all[valais_all.code.isin(codes_of_interest)].groupby(["city","code"], as_index=False)["pcs/m"].mean()
objects_city["object"] = objects_city.code.apply(lambda x: french_names[x])
municipal_results = objects_city.pivot(columns="city", index="object", values="pcs/m").fillna(0)
municipal_results = municipal_results.round(2)
municipal_results.index.name = None
municipal_results.columns.name = None
dist = municipal_results.style.set_table_styles(table_large_font).format('{:,}').applymap_index(rotateText, axis=1)
dist.background_gradient(axis=None, vmin= municipal_results.min().min(), vmax= municipal_results.max().max(), cmap="YlOrBr")
# Out:
# <style type="text/css">
# #T_d8bb5 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_d8bb5 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_d8bb5 tr {
#   font-size: 14px;
# }
# #T_d8bb5 th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_d8bb5 caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# #T_d8bb5_row0_col0, #T_d8bb5_row1_col7, #T_d8bb5_row4_col0, #T_d8bb5_row5_col7, #T_d8bb5_row6_col3 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_d8bb5_row0_col1, #T_d8bb5_row0_col3, #T_d8bb5_row0_col4, #T_d8bb5_row0_col7, #T_d8bb5_row0_col8, #T_d8bb5_row0_col9, #T_d8bb5_row0_col10, #T_d8bb5_row0_col11, #T_d8bb5_row1_col1, #T_d8bb5_row1_col2, #T_d8bb5_row1_col3, #T_d8bb5_row1_col4, #T_d8bb5_row1_col6, #T_d8bb5_row1_col8, #T_d8bb5_row1_col9, #T_d8bb5_row1_col10, #T_d8bb5_row1_col11, #T_d8bb5_row2_col1, #T_d8bb5_row2_col2, #T_d8bb5_row2_col3, #T_d8bb5_row2_col4, #T_d8bb5_row2_col6, #T_d8bb5_row2_col7, #T_d8bb5_row2_col8, #T_d8bb5_row2_col9, #T_d8bb5_row2_col10, #T_d8bb5_row2_col11, #T_d8bb5_row3_col1, #T_d8bb5_row3_col2, #T_d8bb5_row3_col4, #T_d8bb5_row3_col6, #T_d8bb5_row3_col7, #T_d8bb5_row3_col8, #T_d8bb5_row3_col10, #T_d8bb5_row4_col1, #T_d8bb5_row4_col2, #T_d8bb5_row4_col3, #T_d8bb5_row4_col4, #T_d8bb5_row4_col6, #T_d8bb5_row4_col7, #T_d8bb5_row4_col8, #T_d8bb5_row4_col9, #T_d8bb5_row4_col10, #T_d8bb5_row4_col11, #T_d8bb5_row5_col2, #T_d8bb5_row5_col6, #T_d8bb5_row6_col2, #T_d8bb5_row6_col6, #T_d8bb5_row6_col10, #T_d8bb5_row7_col1, #T_d8bb5_row7_col2, #T_d8bb5_row7_col3, #T_d8bb5_row7_col4, #T_d8bb5_row7_col6, #T_d8bb5_row7_col7, #T_d8bb5_row7_col8, #T_d8bb5_row7_col9, #T_d8bb5_row7_col10, #T_d8bb5_row7_col11, #T_d8bb5_row8_col2, #T_d8bb5_row8_col6, #T_d8bb5_row8_col7, #T_d8bb5_row8_col10, #T_d8bb5_row9_col1, #T_d8bb5_row9_col2, #T_d8bb5_row9_col3, #T_d8bb5_row9_col4, #T_d8bb5_row9_col6, #T_d8bb5_row9_col7, #T_d8bb5_row9_col8, #T_d8bb5_row9_col9, #T_d8bb5_row9_col10, #T_d8bb5_row9_col11 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_d8bb5_row0_col2, #T_d8bb5_row5_col4, #T_d8bb5_row5_col10, #T_d8bb5_row8_col1 {
#   background-color: #fffee1;
#   color: #000000;
# }
# #T_d8bb5_row0_col5 {
#   background-color: #fec754;
#   color: #000000;
# }
# #T_d8bb5_row0_col6 {
#   background-color: #fffacb;
#   color: #000000;
# }
# #T_d8bb5_row1_col0, #T_d8bb5_row3_col11 {
#   background-color: #fffedf;
#   color: #000000;
# }
# #T_d8bb5_row1_col5 {
#   background-color: #fff4b6;
#   color: #000000;
# }
# #T_d8bb5_row2_col0, #T_d8bb5_row5_col9, #T_d8bb5_row6_col8, #T_d8bb5_row8_col3 {
#   background-color: #fffcd6;
#   color: #000000;
# }
# #T_d8bb5_row2_col5 {
#   background-color: #fed97c;
#   color: #000000;
# }
# #T_d8bb5_row3_col0 {
#   background-color: #fff9c9;
#   color: #000000;
# }
# #T_d8bb5_row3_col3, #T_d8bb5_row6_col4, #T_d8bb5_row6_col7 {
#   background-color: #fffee2;
#   color: #000000;
# }
# #T_d8bb5_row3_col5 {
#   background-color: #fed471;
#   color: #000000;
# }
# #T_d8bb5_row3_col9 {
#   background-color: #fffddc;
#   color: #000000;
# }
# #T_d8bb5_row4_col5, #T_d8bb5_row6_col0 {
#   background-color: #fff9c6;
#   color: #000000;
# }
# #T_d8bb5_row5_col0 {
#   background-color: #fff8c1;
#   color: #000000;
# }
# #T_d8bb5_row5_col1 {
#   background-color: #fffee0;
#   color: #000000;
# }
# #T_d8bb5_row5_col3, #T_d8bb5_row8_col9 {
#   background-color: #fffbd3;
#   color: #000000;
# }
# #T_d8bb5_row5_col5 {
#   background-color: #feca5d;
#   color: #000000;
# }
# #T_d8bb5_row5_col8 {
#   background-color: #fffdd9;
#   color: #000000;
# }
# #T_d8bb5_row5_col11, #T_d8bb5_row7_col0 {
#   background-color: #fff6ba;
#   color: #000000;
# }
# #T_d8bb5_row6_col1 {
#   background-color: #fffddb;
#   color: #000000;
# }
# #T_d8bb5_row6_col5, #T_d8bb5_row9_col0 {
#   background-color: #fffbd0;
#   color: #000000;
# }
# #T_d8bb5_row6_col9 {
#   background-color: #fed26d;
#   color: #000000;
# }
# #T_d8bb5_row6_col11, #T_d8bb5_row8_col8 {
#   background-color: #fff8c4;
#   color: #000000;
# }
# #T_d8bb5_row7_col5 {
#   background-color: #fffddd;
#   color: #000000;
# }
# #T_d8bb5_row8_col0 {
#   background-color: #fea634;
#   color: #000000;
# }
# #T_d8bb5_row8_col4 {
#   background-color: #fffcd7;
#   color: #000000;
# }
# #T_d8bb5_row8_col5 {
#   background-color: #c94b02;
#   color: #f1f1f1;
# }
# #T_d8bb5_row8_col11 {
#   background-color: #fed573;
#   color: #000000;
# }
# #T_d8bb5_row9_col5 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_d8bb5_level0_col0, #T_d8bb5_level0_col1, #T_d8bb5_level0_col2, #T_d8bb5_level0_col3, #T_d8bb5_level0_col4, #T_d8bb5_level0_col5, #T_d8bb5_level0_col6, #T_d8bb5_level0_col7, #T_d8bb5_level0_col8, #T_d8bb5_level0_col9, #T_d8bb5_level0_col10, #T_d8bb5_level0_col11 {
#   writing-mode: vertical-lr;
#   transform: rotate(-180deg);
#   padding: 10px;
#   margins: 0;
#   vertical-align: baseline;
# }
# </style>
# <table id="T_d8bb5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8bb5_level0_col0" class="col_heading level0 col0" >Bouveret</th>
#       <th id="T_d8bb5_level0_col1" class="col_heading level0 col1" >Crans-Montana</th>
#       <th id="T_d8bb5_level0_col2" class="col_heading level0 col2" >Leuk</th>
#       <th id="T_d8bb5_level0_col3" class="col_heading level0 col3" >Nendaz</th>
#       <th id="T_d8bb5_level0_col4" class="col_heading level0 col4" >Riddes</th>
#       <th id="T_d8bb5_level0_col5" class="col_heading level0 col5" >Saint-Gingolph</th>
#       <th id="T_d8bb5_level0_col6" class="col_heading level0 col6" >Salgesch</th>
#       <th id="T_d8bb5_level0_col7" class="col_heading level0 col7" >Sion</th>
#       <th id="T_d8bb5_level0_col8" class="col_heading level0 col8" >Troistorrents</th>
#       <th id="T_d8bb5_level0_col9" class="col_heading level0 col9" >Val de Bagnes</th>
#       <th id="T_d8bb5_level0_col10" class="col_heading level0 col10" >Val-d'Illiez</th>
#       <th id="T_d8bb5_level0_col11" class="col_heading level0 col11" >Val-de-Charmey</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8bb5_level0_row0" class="row_heading level0 row0" >Bâche, feuille plastique industrielle</th>
#       <td id="T_d8bb5_row0_col0" class="data row0 col0" >0.02</td>
#       <td id="T_d8bb5_row0_col1" class="data row0 col1" >0.0</td>
#       <td id="T_d8bb5_row0_col2" class="data row0 col2" >0.06</td>
#       <td id="T_d8bb5_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_d8bb5_row0_col4" class="data row0 col4" >0.0</td>
#       <td id="T_d8bb5_row0_col5" class="data row0 col5" >1.75</td>
#       <td id="T_d8bb5_row0_col6" class="data row0 col6" >0.38</td>
#       <td id="T_d8bb5_row0_col7" class="data row0 col7" >0.0</td>
#       <td id="T_d8bb5_row0_col8" class="data row0 col8" >0.0</td>
#       <td id="T_d8bb5_row0_col9" class="data row0 col9" >0.0</td>
#       <td id="T_d8bb5_row0_col10" class="data row0 col10" >0.0</td>
#       <td id="T_d8bb5_row0_col11" class="data row0 col11" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_d8bb5_level0_row1" class="row_heading level0 row1" >Cartouches de fusil de chasse</th>
#       <td id="T_d8bb5_row1_col0" class="data row1 col0" >0.1</td>
#       <td id="T_d8bb5_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_d8bb5_row1_col2" class="data row1 col2" >0.0</td>
#       <td id="T_d8bb5_row1_col3" class="data row1 col3" >0.0</td>
#       <td id="T_d8bb5_row1_col4" class="data row1 col4" >0.0</td>
#       <td id="T_d8bb5_row1_col5" class="data row1 col5" >0.68</td>
#       <td id="T_d8bb5_row1_col6" class="data row1 col6" >0.0</td>
#       <td id="T_d8bb5_row1_col7" class="data row1 col7" >0.02</td>
#       <td id="T_d8bb5_row1_col8" class="data row1 col8" >0.0</td>
#       <td id="T_d8bb5_row1_col9" class="data row1 col9" >0.0</td>
#       <td id="T_d8bb5_row1_col10" class="data row1 col10" >0.0</td>
#       <td id="T_d8bb5_row1_col11" class="data row1 col11" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_d8bb5_level0_row2" class="row_heading level0 row2" >Coton-tige</th>
#       <td id="T_d8bb5_row2_col0" class="data row2 col0" >0.23</td>
#       <td id="T_d8bb5_row2_col1" class="data row2 col1" >0.0</td>
#       <td id="T_d8bb5_row2_col2" class="data row2 col2" >0.0</td>
#       <td id="T_d8bb5_row2_col3

# %% [markdown]
# ### Résultats par utilité d'objet

# %% [markdown]
# L'utilité d'un objet est basée sur l'utilisation de l'objet avant qu'il ne soit jeté ou sur la description de l'objet si l'utilisation d'origine n'est pas déterminée.
#
# * __eaux usées :__ objets rejetés par les stations d'épuration des eaux, y compris les objets susceptibles d'être jetés dans les toilettes
# * __microplastiques (< 5 mm) :__ plastiques fragmentés et résines plastiques de préproduction
# * __infrastructures :__ éléments liés à la construction et à l'entretien des bâtiments, des routes et de l'approvisionnement en eau et en électricité
# * __alimentation et boissons :__ tous les matériaux liés à la consommation d'aliments et de boissons
# * __agriculture :__ principalement les feuilles industrielles, c'est-à-dire le paillage et les couvertures de rangs, les serres, la fumigation des sols, l'enrubannage des balles. Comprend les plastiques durs pour les clôtures agricoles, les pots de fleurs, etc.
# * __tabac :__ principalement les filtres de cigarettes, y compris tout le matériel lié au tabagisme
# * __Loisirs :__ objets liés aux sports et aux loisirs, tels que la pêche, la chasse, la randonnée, etc.
# * __Emballages non alimentaires et boissons :__ matériaux d'emballage non identifiés comme étant liés à l'alimentation, aux boissons ou au tabac.
# * __fragments de plastique :__ morceaux de plastique d'origine ou d'utilisation indéterminée
# * __articles personnels :__ accessoires, hygiène et vêtements

# %%
valais_all["groupname"] = valais_all.code.apply(lambda x: code_g.loc[x])

cg_agg = valais_all.groupby(["loc_date", "city", "groupname"], as_index=False)["pcs/m"].sum()
cg_agg["groupname"] = cg_agg.groupname.apply(lambda x: group_names[x])
cg_agg_group = cg_agg.groupby(["city","groupname"], as_index=False)["pcs/m"].median()

cg_display = cg_agg_group.pivot(columns="city", index="groupname", values=["pcs/m"])
cg_display=cg_display.round(2)
cg_display.index.name = None
cg_display.columns = cg_display.columns.droplevel()
cg_display.fillna(0, inplace=True)
cg_display.columns.name = None

dist = cg_display.style.set_table_styles(table_large_font).format('{:,}').applymap_index(rotateText, axis=1)
dist.background_gradient(axis=None, vmin=cg_display.min().min(), vmax= cg_display.max().max(), cmap="YlOrBr")
# Out:
# <style type="text/css">
# #T_536f5 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_536f5 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_536f5 tr {
#   font-size: 14px;
# }
# #T_536f5 th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_536f5 caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# #T_536f5_row0_col0, #T_536f5_row0_col1, #T_536f5_row0_col3, #T_536f5_row0_col4, #T_536f5_row0_col7, #T_536f5_row0_col8, #T_536f5_row0_col9, #T_536f5_row0_col10, #T_536f5_row0_col11, #T_536f5_row1_col2, #T_536f5_row1_col6, #T_536f5_row2_col1, #T_536f5_row2_col2, #T_536f5_row2_col3, #T_536f5_row2_col4, #T_536f5_row2_col6, #T_536f5_row2_col7, #T_536f5_row2_col8, #T_536f5_row2_col9, #T_536f5_row2_col10, #T_536f5_row2_col11, #T_536f5_row3_col2, #T_536f5_row3_col6, #T_536f5_row3_col7, #T_536f5_row3_col10, #T_536f5_row4_col1, #T_536f5_row4_col2, #T_536f5_row4_col3, #T_536f5_row4_col4, #T_536f5_row4_col6, #T_536f5_row4_col7, #T_536f5_row4_col8, #T_536f5_row4_col9, #T_536f5_row4_col10, #T_536f5_row4_col11, #T_536f5_row5_col1, #T_536f5_row5_col2, #T_536f5_row5_col3, #T_536f5_row5_col4, #T_536f5_row5_col6, #T_536f5_row5_col8, #T_536f5_row5_col9, #T_536f5_row5_col10, #T_536f5_row5_col11, #T_536f5_row6_col1, #T_536f5_row6_col2, #T_536f5_row6_col3, #T_536f5_row6_col4, #T_536f5_row6_col6, #T_536f5_row6_col7, #T_536f5_row6_col8, #T_536f5_row6_col9, #T_536f5_row6_col10, #T_536f5_row6_col11, #T_536f5_row7_col2, #T_536f5_row7_col6, #T_536f5_row7_col10 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_536f5_row0_col2, #T_536f5_row1_col4, #T_536f5_row1_col10 {
#   background-color: #fffee0;
#   color: #000000;
# }
# #T_536f5_row0_col5 {
#   background-color: #fedd84;
#   color: #000000;
# }
# #T_536f5_row0_col6, #T_536f5_row1_col9 {
#   background-color: #fff8c0;
#   color: #000000;
# }
# #T_536f5_row1_col0 {
#   background-color: #fee18c;
#   color: #000000;
# }
# #T_536f5_row1_col1 {
#   background-color: #fffddd;
#   color: #000000;
# }
# #T_536f5_row1_col3 {
#   background-color: #fff9c6;
#   color: #000000;
# }
# #T_536f5_row1_col5 {
#   background-color: #eb6f14;
#   color: #f1f1f1;
# }
# #T_536f5_row1_col7, #T_536f5_row5_col7, #T_536f5_row6_col5 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_536f5_row1_col8 {
#   background-color: #fffcd4;
#   color: #000000;
# }
# #T_536f5_row1_col11 {
#   background-color: #fee89d;
#   color: #000000;
# }
# #T_536f5_row2_col0 {
#   background-color: #fffbd3;
#   color: #000000;
# }
# #T_536f5_row2_col5 {
#   background-color: #fec550;
#   color: #000000;
# }
# #T_536f5_row3_col0 {
#   background-color: #e46710;
#   color: #f1f1f1;
# }
# #T_536f5_row3_col1 {
#   background-color: #fffedf;
#   color: #000000;
# }
# #T_536f5_row3_col3 {
#   background-color: #fffbcf;
#   color: #000000;
# }
# #T_536f5_row3_col4, #T_536f5_row7_col5 {
#   background-color: #fffbd0;
#   color: #000000;
# }
# #T_536f5_row3_col5 {
#   background-color: #c44802;
#   color: #f1f1f1;
# }
# #T_536f5_row3_col8 {
#   background-color: #fff4b5;
#   color: #000000;
# }
# #T_536f5_row3_col9 {
#   background-color: #fffaca;
#   color: #000000;
# }
# #T_536f5_row3_col11 {
#   background-color: #feae3b;
#   color: #000000;
# }
# #T_536f5_row4_col0 {
#   background-color: #fff9c9;
#   color: #000000;
# }
# #T_536f5_row4_col5 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_536f5_row5_col0, #T_536f5_row7_col4, #T_536f5_row7_col7 {
#   background-color: #fffee1;
#   color: #000000;
# }
# #T_536f5_row5_col5 {
#   background-color: #ffeea9;
#   color: #000000;
# }
# #T_536f5_row6_col0, #T_536f5_row7_col0 {
#   background-color: #fff7bc;
#   color: #000000;
# }
# #T_536f5_row7_col1 {
#   background-color: #fffcd6;
#   color: #000000;
# }
# #T_536f5_row7_col3 {
#   background-color: #fffee2;
#   color: #000000;
# }
# #T_536f5_row7_col8 {
#   background-color: #ffface;
#   color: #000000;
# }
# #T_536f5_row7_col9 {
#   background-color: #fea937;
#   color: #000000;
# }
# #T_536f5_row7_col11 {
#   background-color: #fff3b4;
#   color: #000000;
# }
# #T_536f5_level0_col0, #T_536f5_level0_col1, #T_536f5_level0_col2, #T_536f5_level0_col3, #T_536f5_level0_col4, #T_536f5_level0_col5, #T_536f5_level0_col6, #T_536f5_level0_col7, #T_536f5_level0_col8, #T_536f5_level0_col9, #T_536f5_level0_col10, #T_536f5_level0_col11 {
#   writing-mode: vertical-lr;
#   transform: rotate(-180deg);
#   padding: 10px;
#   margins: 0;
#   vertical-align: baseline;
# }
# </style>
# <table id="T_536f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_536f5_level0_col0" class="col_heading level0 col0" >Bouveret</th>
#       <th id="T_536f5_level0_col1" class="col_heading level0 col1" >Crans-Montana</th>
#       <th id="T_536f5_level0_col2" class="col_heading level0 col2" >Leuk</th>
#       <th id="T_536f5_level0_col3" class="col_heading level0 col3" >Nendaz</th>
#       <th id="T_536f5_level0_col4" class="col_heading level0 col4" >Riddes</th>
#       <th id="T_536f5_level0_col5" class="col_heading level0 col5" >Saint-Gingolph</th>
#       <th id="T_536f5_level0_col6" class="col_heading level0 col6" >Salgesch</th>
#       <th id="T_536f5_level0_col7" class="col_heading level0 col7" >Sion</th>
#       <th id="T_536f5_level0_col8" class="col_heading level0 col8" >Troistorrents</th>
#       <th id="T_536f5_level0_col9" class="col_heading level0 col9" >Val de Bagnes</th>
#       <th id="T_536f5_level0_col10" class="col_heading level0 col10" >Val-d'Illiez</th>
#       <th id="T_536f5_level0_col11" class="col_heading level0 col11" >Val-de-Charmey</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_536f5_level0_row0" class="row_heading level0 row0" >agriculture</th>
#       <td id="T_536f5_row0_col0" class="data row0 col0" >0.0</td>
#       <td id="T_536f5_row0_col1" class="data row0 col1" >0.0</td>
#       <td id="T_536f5_row0_col2" class="data row0 col2" >0.06</td>
#       <td id="T_536f5_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_536f5_row0_col4" class="data row0 col4" >0.0</td>
#       <td id="T_536f5_row0_col5" class="data row0 col5" >0.92</td>
#       <td id="T_536f5_row0_col6" class="data row0 col6" >0.38</td>
#       <td id="T_536f5_row0_col7" class="data row0 col7" >0.0</td>
#       <td id="T_536f5_row0_col8" class="data row0 col8" >0.0</td>
#       <td id="T_536f5_row0_col9" class="data row0 col9" >0.0</td>
#       <td id="T_536f5_row0_col10" class="data row0 col10" >0.0</td>
#       <td id="T_536f5_row0_col11" class="data row0 col11" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_536f5_level0_row1" class="row_heading level0 row1" >alimentation et boissons</th>
#       <td id="T_536f5_row1_col0" class="data row1 col0" >0.87</td>
#       <td id="T_536f5_row1_col1" class="data row1 col1" >0.09</td>
#       <td id="T_536f5_row1_col2" class="data row1 col2" >0.0</td>
#       <td id="T_536f5_row1_col3" class="data row1 col3" >0.32</td>
#       <td id="T_536f5_row1_col4" class="data row1 col4" >0.06</td>
#       <td id="T_536f5_row1_col5" class="data row1 col5" >2.1</td>
#       <td id="T_536f5_row1_col6" class="data row1 col6" >0.0</td>
#       <td id="T_536f5_row1_col7" class="data row1 col7" >0.02</td>
#       <td id="T_536f5_row1_col8" class="data row1 col8" >0.17</td>
#       <td id="T_536f5_row1_col9" class="data row1 col9" >0.38</td>
#       <td id="T_536f5_row1_col10" class="data row1 col10" >0.06</td>
#       <td id="T_536f5_row1_col11" class="data row1 col11" >0.73</td>
#     </tr>
#     <tr>
#       <th id="T_536f5_level0_row2" class="row_heading level0 row2" >eaux usées</th>
#       <td id="T_536f5_row2_col0" class="data row2 col0" >0.19</td>
#       <td id="T_536f5_row2_col1" class="data row2 col1" >0.0</td>
#       <td id="T_536f5_row2_col2" class="data row2 col2" >0.0</td>
#       <td id="T_536f5_row2_col3" class="data row2 col3" >0.0</td>
#       <td id="T_536f5_row2_col4" class="data row2 col4" >0.0</td>
#       <td id="T_536f5_row2_col5" class="data row2 col5" >1.25</td>
#       <td id="T_536f5_row2_col6" class="data row2 col6" >0.0</td>
#       <td id="T_536f5_row2_col7" class="data row2 col7" >0.0</td>
#       <td id="T_536f5_row2_col8" class="data row2 col8" >0.0</td>
#       <td id="T_536f5_row2_col9" class="data row2 col9" >0.0</td>
#       <td id="T_536f5_row2_

# %% [markdown]
# ## Lieux d'enquêtes

# %%
survey_locations = valais_all[["slug", "city", "zone"]].drop_duplicates()
survey_locations.set_index("slug", inplace=True)
survey_locations.index.name = None
survey_locations.style.set_table_styles(table_large_font)
# Out:
# <style type="text/css">
# #T_c86a0 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_c86a0 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_c86a0 tr {
#   font-size: 14px;
# }
# #T_c86a0 th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_c86a0 caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# </style>
# <table id="T_c86a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c86a0_level0_col0" class="col_heading level0 col0" >city</th>
#       <th id="T_c86a0_level0_col1" class="col_heading level0 col1" >zone</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c86a0_level0_row0" class="row_heading level0 row0" >les-glariers</th>
#       <td id="T_c86a0_row0_col0" class="data row0 col0" >Riddes</td>
#       <td id="T_c86a0_row0_col1" class="data row0 col1" >rivière</td>
#     </tr>
#     <tr>
#       <th id="T_c86a0_level0_row1" class="row_heading level0 row1" >les-vieux-ronquoz</th>
#       <td id="T_c86a0_row1_col0" class="data row1 col0" >Sion</td>
#       <td id="T_c86a0_row1_col1" class="data row1 col1" >rivière</td>
#     </tr>
#     <tr>
#       <th id="T_c86a0_level0_row2" class="row_heading level0 row2" >leuk-mattenstrasse</th>
#       <td id="T_c86a0_row2_col0" class="data row2 col0" >Leuk</td>
#       <td id="T_c86a0_row2_col1" class="data row2 col1" >rivière</td>
#     </tr>
#     <tr>
#       <th id="T_c86a0_level0_row3" class="row_heading level0 row3" >tschilljus</th>
#       <td id="T_c86a0_row3_col0" class="data row3 col0" >Salgesch</td>
#       <td id="T_c86a0_row3_col1" class="data row3 col1" >rivière</td>
#     </tr>
#     <tr>
#       <th id="T_c86a0_level0_row4" class="row_heading level0 row4" >bouveret</th>
#       <td id="T_c86a0_row4_col0" class="data row4 col0" >Bouveret</td>
#       <td id="T_c86a0_row4_col1" class="data row4 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_c86a0_level0_row5" class="row_heading level0 row5" >grand-clos</th>
#       <td id="T_c86a0_row5_col0" class="data row5 col0" >Saint-Gingolph</td>
#       <td id="T_c86a0_row5_col1" class="data row5 col1" >lac</td>
#     </tr>
#     <tr>
#       <th id="T_c86a0_level0_row6" class="row_heading level0 row6" >charmey</th>
#       <td id="T_c86a0_row6_col0" class="data row6 col0" >Val-de-Charmey</td>
#       <td id="T_c86a0_row6_col1" class="data row6 col1" >montagne</td>
#     </tr>
#     <tr>
#       <th id="T_c86a0_level0_row7" class="row_heading level0 row7" >crans-montana</th>
#       <td id="T_c86a0_row7_col0" class="data row7 col0" >Crans-Montana</td>
#       <td id="T_c86a0_row7_col1" class="data row7 col1" >montagne</td>
#     </tr>
#     <tr>
#       <th id="T_c86a0_level0_row8" class="row_heading level0 row8" >la-tzoumaz</th>
#       <td id="T_c86a0_row8_col0" class="data row8 col0" >Riddes</td>
#       <td id="T_c86a0_row8_col1" class="data row8 col1" >montagne</td>
#     </tr>
#     <tr>
#       <th id="T_c86a0_level0_row9" class="row_heading level0 row9" >les-crosets</th>
#       <td id="T_c86a0_row9_col0" class="data row9 col0" >Val-d'Illiez</td>
#       <td id="T_c86a0_row9_col1" class="data row9 col1" >montagne</td>
#     </tr>
#     <tr>
#       <th id="T_c86a0_level0_row10" class="row_heading level0 row10" >morgins</th>
#       <td id="T_c86a0_row10_col0" class="data row10 col0" >Troistorrents</td>
#       <td id="T_c86a0_row10_col1" class="data row10 col1" >montagne</td>
#     </tr>
#     <tr>
#       <th id="T_c86a0_level0_row11" class="row_heading level0 row11" >nendaz</th>
#       <td id="T_c86a0_row11_col0" class="data row11 col0" >Nendaz</td>
#       <td id="T_c86a0_row11_col1" class="data row11 col1" >montagne</td>
#     </tr>
#     <tr>
#       <th id="T_c86a0_level0_row12" class="row_heading level0 row12" >verbier</th>
#       <td id="T_c86a0_row12_col0" class="data row12 col0" >Val de Bagnes</td>
#       <td id="T_c86a0_row12_col1" class="data row12 col1" >montagne</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Inventaire complet

# %%
operators = {
    "quantity":"sum",
    "pcs/m": "median",
}

valais_all["fail"] = valais_all["quantity"] > 0
code_fails = valais_all.groupby("code").fail.sum()
code_fail_rate = code_fails/valais_all.loc_date.nunique()


inventory = valais_all.groupby("code", as_index=False).agg(operators)

# %%
inventory["fail_rate"] = inventory.code.apply(lambda x: code_fail_rate.loc[x])
inventory = inventory[inventory.quantity > 0]
inventory["object"] =inventory.code.apply(lambda x: french_names[x])
inventory = inventory[["code", "object", "quantity", "pcs/m", "fail_rate"]]
inventory.set_index("code", inplace=True)
inventory["quantity"] = inventory.quantity.astype("int")

inventory.sort_values(by="quantity", inplace=True, ascending=False)
inventory.rename(columns=display_names, inplace=True)
inventory.index.name = None

# %%
inventory.style.set_table_styles(table_large_font).format(precision=3)
# Out:
# <style type="text/css">
# #T_c911c tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_c911c tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_c911c tr {
#   font-size: 14px;
# }
# #T_c911c th:nth-child(1) {
#   background-color: #FFF;
#   text-align: right;
# }
# #T_c911c caption {
#   font-size: 14px;
#   font-style: italic;
#   caption-side: bottom;
#   text-align: left;
#   margin-top: 10px;
# }
# </style>
# <table id="T_c911c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c911c_level0_col0" class="col_heading level0 col0" >objet</th>
#       <th id="T_c911c_level0_col1" class="col_heading level0 col1" >quantité</th>
#       <th id="T_c911c_level0_col2" class="col_heading level0 col2" >pcs/m</th>
#       <th id="T_c911c_level0_col3" class="col_heading level0 col3" >taux d'échec</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c911c_level0_row0" class="row_heading level0 row0" >Gfrags</th>
#       <td id="T_c911c_row0_col0" class="data row0 col0" >Plastiques fragmentés</td>
#       <td id="T_c911c_row0_col1" class="data row0 col1" >2552</td>
#       <td id="T_c911c_row0_col2" class="data row0 col2" >1.755</td>
#       <td id="T_c911c_row0_col3" class="data row0 col3" >0.821</td>
#     </tr>
#     <tr>
#       <th id="T_c911c_level0_row1" class="row_heading level0 row1" >Gfoam</th>
#       <td id="T_c911c_row1_col0" class="data row1 col0" >Polystyrène expansé fragmenté</td>
#       <td id="T_c911c_row1_col1" class="data row1 col1" >1991</td>
#       <td id="T_c911c_row1_col2" class="data row1 col2" >0.510</td>
#       <td id="T_c911c_row1_col3" class="data row1 col3" >0.607</td>
#     </tr>
#     <tr>
#       <th id="T_c911c_level0_row2" class="row_heading level0 row2" >G30</th>
#       <td id="T_c911c_row2_col0" class="data row2 col0" >Emballages de bonbons, de snacks</td>
#       <td id="T_c911c_row2_col1" class="data row2 col1" >881</td>
#       <td id="T_c911c_row2_col2" class="data row2 col2" >0.355</td>
#       <td id="T_c911c_row2_col3" class="data row2 col3" >0.857</td>
#     </tr>
#     <tr>
#       <th id="T_c911c_level0_row3" class="row_heading level0 row3" >Gcaps</th>
#       <td id="T_c911c_row3_col0" class="data row3 col0" >Couvercles de bouteilles en plastique</td>
#       <td id="T_c911c_row3_col1" class="data row3 col1" >766</td>
#       <td id="T_c911c_row3_col2" class="data row3 col2" >0.291</td>
#       <td id="T_c911c_row3_col3" class="data row3 col3" >0.714</td>
#     </tr>
#     <tr>
#       <th id="T_c911c_level0_row4" class="row_heading level0 row4" >G95</th>
#       <td id="T_c911c_row4_col0" class="data row4 col0" >Coton-tige</td>
#       <td id="T_c911c_row4_col1" class="data row4 col1" >653</td>
#       <td id="T_c911c_row4_col2" class="data row4 col2" >0.186</td>
#       <td id="T_c911c_row4_col3" class="data row4 col3" >0.571</td>
#     </tr>
#     <tr>
#       <th id="T_c911c_level0_row5" class="row_heading level0 row5" >G67</th>
#       <td id="T_c911c_row5_col0" class="data row5 col0" >Bâche, feuille plastique industrielle</td>
#       <td id="T_c911c_row5_col1" class="data row5 col1" >608</td>
#       <td id="T_c911c_row5_col2" class="data row5 col2" >0.084</td>
#       <td id="T_c911c_row5_col3" class="data row5 col3" >0.571</td>
#     </tr>
#     <tr>
#       <th id="T_c911c_level0_row6" class="row_heading level0 row6" >G27</th>
#       <td id="T_c911c_row6_col0" class="data row6 col0" >Mégots et filtres à cigarettes</td>
#       <td id="T_c911c_row6_col1" class="data row6 col1" >455</td>
#       <td id="T_c911c_row6_col2" class="data row6 col2" >0.110</td>
#       <td id="T_c911c_row6_col3" class="data row6 col3" >0.786</td>
#     </tr>
#     <tr>
#       <th id="T_c911c_level0_row7" class="row_heading level0 row7" >G112</th>
#       <td id="T_c911c_row7_col0" class="data row7 col0" >Pellets industriels (GPI)</td>
#       <td id="T_c911c_row7_col1" class="data row7 col1" >336</td>
#       <td id="T_c911c_row7_col2" class="data row7 col2" >0.000</td>
#       <td id="T_c911c_row7_col3" class="data row7 col3" >0.393</td>
#     </tr>
#     <tr>
#       <th id="T_c911c_level0_row8" class="row_heading level0 row8" >G70</th>
#       <td id="T_c911c_row8_col0" class="data row8 col0" >Cartouches de fusil de chasse</td>
#       <td id="T_c911c_row8_col1" class="data row8 col1" >315</td>
#       <td id="T_c911c_row8_col2" class="data row8 col2" >0.062</td>
#       <td id="T_c911c_row8_col3" class="data row8 col3" >0.643</td>
#     </tr>
#     <tr>
#       <th id="T_c911c_level0_row9" class="row_heading level0 row9" >G10</th>
#       <td id="T_c911c_row9_col0" class="data row9 col0" >Emballage fast food</td>
#       <td id="T_c911c_row9_col1" class="data row9 col1" >186</td>
#       <td id="T_c911c_row9_col2" class="data row9 col2" >0.029</td>
#       <td id="T_c911c_row9_col3" class="data row9 col3" >0.571</td>
#     </tr>
#   </tbody>
# </table>

# %%
today = dt.datetime.now().date().strftime("%d/%m/%Y")
where = "Biel, CH"

my_block = f"""
<br />
<br />
This script updated {today} in {where}

\u2764\ufe0f what you do - faites ce que vous \u2764\ufe0f
"""

md(my_block)
# Out:
# <br />
# <br />
# This script updated 09/09/2023 in Biel, CH
#
# ❤️ what you do - faites ce que vous ❤️

# %%
# %watermark --iversions -b -r
# Out:
# Git repo: https://github.com/hammerdirt-analyst/cantonal_reports.git
#
# Git branch: main
#
# json      : 2.0.9
# seaborn   : 0.12.2
# pandas    : 2.0.3
# numpy     : 1.25.2
# matplotlib: 3.7.1
